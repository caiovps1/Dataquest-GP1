# %% [markdown]
# # **Tipos de *apps* com maiores probabilidades de lucro na Google Play e na App Store**
#
# A CVTech é uma *startup* fícticia de desenvolvimento de aplicativos *mobile*. Para maior embasamento na escolha do aplicativo inaugural da CVTech, os gestores desejam que seja feita uma pesquisa das aplicações mais lucrativas na Google Play e App Store, plataformas que desejam utilizar para disponibilização de seu produto, que segundo informado, será gratuito e em inglês, sendo a fonte de lucros os anúncios dentro do próprio aplicativo.
#
# Este projeto foi feito para nortear a escolha do tipo de aplicativo a ser desenvolvido de forma a maximizar a segurança do investimento.
#
# Pelo produto ser gratuito, a variável determinante para a lucratividade do aplicativo é o número de usuários do mesmo, pois quanto mais pessoas usando-o, mais atraente o aplicativo é para anunciantes. Desta forma, o objetivo específico deste projeto é responder à pergunta: qual tipo de aplicativo *mobile* é mais provável que atraia usuários?
#
#
#
# ## **Encontrando, abrindo e explorando os *data sets***
#
# Coletar dados de milhões de aplicativos requer muito tempo e dinheiro, e para evitar esse investimento, procuramos dados relevantes sem custos. Felizmente, foram encontrados dois *data sets* que são adequados para este projeto.
#
# - O [primeiro *data set*](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps "App Store Apps") possui dados de mais de 7200 aplicativos da App Store;
# - O [segundo *data set*](https://www.kaggle.com/lava18/google-play-store-apps "Google Play Apps") possui dados de mais de 10.000 aplicativos da Google Play.
#
# Começamos com a definição da função `explore_data`, criada para facilitar a visualização de *data sets*, e em seguida, abrimos, lemos e exploramos os *data sets*, para maior familiarização.

# %%
# Definição da função explore_data

def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n')

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
# Abrindo e lendo os data sets

from csv import reader

# Abrindo, lendo e preparando o dataset de apps da App Store
opened_file = open('AppleStore.csv', encoding="utf8")
read_file = reader(opened_file)
ios_total = list(read_file)
ios_header = ios_total[0]
ios = ios_total[1:]

# Abrindo, lendo e preparando o dataset de apps da Google Play
opened_file = open('googleplaystore.csv', encoding="utf8")
read_file = reader(opened_file)
android_total = list(read_file)
android_header = android_total[0]
android = android_total[1:]

# %%
# Explorando inicialmente os data sets

print ('\n Primeiras 5 linhas da App Store \n')
explore_data(ios, 0, 5, rows_and_columns=True)
print ('\n Primeiras 5 linhas da Google Play \n')
explore_data(android, 0, 5, rows_and_columns=True)
# Out:
#  Primeiras 5 linhas da App Store
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# ['4', '282614216', 'eBay: Best App to Buy, Sell, Save! Online Shopping', '128512000', 'USD', '0', '262241', '649', '4', '4.5', '5.10.0', '12+', 'Shopping', '37', '5', '9', '1']
#
#
# ['5', '282935706', 'Bible', '92774400', 'USD', '0', '985920', '5320', '4.5', '5', '7.5.1', '4+', 'Reference', '37', '5', '45', '1']
#
#
# Number of rows: 7197
# Number of columns: 17
#
#  Primeiras 5 linhas da Google Play
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %%
# Imprimindo os cabeçalhos dos data sets

print('\n Cabeçalho da App Store \n')
print(ios_header)
print('\n Cabeçalho da Google Play \n')
print(android_header)
# Out:
#  Cabeçalho da App Store
#
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#  Cabeçalho da Google Play
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# ## Limpeza de Dados (Data Cleaning)
#
# Antes de começar a trabalhar diretamente com a interpretação dos dados, é necessário preparar os nossos *data sets* para isso.
#
# ### Retirada de linha preenchida incorretamente
#
# Primeiramente, foi feita uma pesquisa acerca do que outros usuários do Kaggle discutiram sobre os dois *data sets* adquiridos. Notou-se que a entrada número 10472 do data set do Google Play está errada, havendo um deslocamento de coluna. Abaixo, confirma-se o erro.

# %%
# Checando o erro.
print(android[10471])
print(android[10472])
print(android_total[10473])
# Out:
# ['Xposed Wi-Fi-Pwd', 'PERSONALIZATION', '3.5', '1042', '404k', '100,000+', 'Free', '0', 'Everyone', 'Personalization', 'August 5, 2014', '3.0.0', '4.0.3 and up']
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# Podemos notar que a linha referente ao aplicativo 'Life Made WI-Fi Touchscreen Photo Frame' não está preenchida corretamente, havendo um deslocamento de coluna devido ao não preenchimento da aba Category. Desta forma, essas linhas foram deletadas dos *data sets* correspondentes.

# %%
del android[10472]
del android_total[10473]

# %% [markdown]
# ### Remoção de redundâncias
#
# Retirada a linha não preenchida corretamente, devemos fazer outro tratamento básico nos *data sets*, que é a remoção de redundâncias. Levando em consideração que cada linha dos *data sets* equivale a um aplicativo, se houver quaisquer repetições, devemos eliminá-las, para não comprometer as posteriores conclusões. Para tal, primeiramente devemos identificar essas repetições.

# %%
android_apps = []
android_repeated_rows = []
android_repeated_apps = []
row_android = 0

for app in android:
    name = app[0]
    if name in android_apps:
        android_repeated_rows.append(row_android)
        android_repeated_apps.append(name)
    else:
        android_apps.append(name)
    row_android += 1
        
print('Número de apps totais avaliados na Google Play:', len(android_apps))
print('Número de linhas repetidas no data set da Google Play, ou seja, número de repetições:', len(android_repeated_rows))

ios_apps = []
ios_repeated_rows = []
ios_repeated_apps = []
row_ios = 0

for app in ios:
    name = app[2]
    if name in ios_apps:
        ios_repeated_rows.append(row_ios)
        ios_repeated_apps.append(name)
    else:
        ios_apps.append(name)
    row_ios += 1
        
print('Número de apps totais avaliados na App Store:', len(ios_apps))
print('Número de linhas repetidas no data set da App Store, ou seja, número de repetições:', len(ios_repeated_rows))
# Out:
# Número de apps totais avaliados na Google Play: 9659
# Número de linhas repetidas no data set da Google Play, ou seja, número de repetições: 1181
# Número de apps totais avaliados na App Store: 7195
# Número de linhas repetidas no data set da App Store, ou seja, número de repetições: 2

# %% [markdown]
# Para a retirada de linhas de aplicativos repetidos, é válida a pergunta: qual linha retirar?
# Ao analisar as linhas repetidas, nota-se que outras colunas diferentes do nome mudam, significando dados diferentes para um mesmo aplicativo. Com isso, é mais razoável manter as linhas com os dados mais atuais do aplicativo em questão. Podemos saber qual é esta analisando a coluna de total de *downloads*, o que significa uma coleta de dados mais próxima do atual.
#
# Desta forma, o próximo pedaço de código avalia qual é a linha com dados mais atuais dentre as repetidas e exclui as outras.

# %%
reviews_max_android = {}
reviews_max_ios = {}

for app in android:
    name = app[0]
    n_reviews = float(app[3])
    if (name in reviews_max_android and reviews_max_android[name] < n_reviews) or (name not in reviews_max_android):
        reviews_max_android[name] = n_reviews
        
for app in ios:
    name = app[2]
    n_reviews = float(app[6])
    if (name in reviews_max_ios and reviews_max_ios[name] < n_reviews) or (name not in reviews_max_ios):
        reviews_max_ios[name] = n_reviews

# %% [markdown]
# Desta forma, criamos um dicionário com as *keys* sendo os nomes dos *apps* que compõem o *data set* e
# os *values* sendo o número máximo de avaliações no *data set* original.
#
# Agora devemos eliminar do *data set* original as linhas que possuem *apps* repetidos e que não sejam a linha
# com maior número de *reviews*.

# %%
android_clean = []
android_names = []
for app in android:
    name = app[0]
    n_reviews = float(app[3])
    if (n_reviews == reviews_max_android[name]) and (name not in android_names):
        android_clean.append(app)
        android_names.append(name)
        

ios_clean = []
ios_names = []
for app in ios:
    name = app[2]
    n_reviews = float(app[6])
    if (n_reviews == reviews_max_ios[name]) and (name not in ios_names):
        ios_clean.append(app)
        ios_names.append(name)
        
print(len(android_clean))
print(len(android_names))
print(len(ios_clean))
print(len(ios_names))
# Out:
# 9659
# 9659
# 7195
# 7195

# %% [markdown]
# ### Retirando *apps* que não sejam em inglês
#
# A CVTech é uma *startup* voltada para o público falante de inglês e, com isso, é necessário retirar os *apps* que não sejam em inglês de nossos *data sets*. Uma maneira eficaz, porém não perfeita, para tal é eliminar de nossas listas todos os aplicativos que possuem caracteres não usuais na língua inglesa.
#
# Para isso, definimos a função `is_english`, que dada uma *string*, retorna se a mesma é em inglês ou não a partir de análise de seus caracteres. Se a *string* possuir mais de 3 caracteres não usuais da língua inglesa, retorna-se falso. Caso contrário, retorna-se verdadeiro.
#
# O motivo para a adoção do número 3 de caracteres é para evitar a exclusão de *apps* em inglês, mas que possuam caracteres considerados não usuais no inglês, como ™ e ®.

# %%
def is_english(string, num_of_char):
    non_ascii = 0
    for char in string:
        char_code = ord(char)
        if char_code > 127:
            non_ascii += 1
    if non_ascii > num_of_char:
        return False
    else:
        return True
    
    
android_english = []
ios_english = []

for app in android_clean:
    name = app[0]
    if is_english(name, 3):
        android_english.append(app)
        
for app in ios_clean:
    name = app[2]
    if is_english(name, 3):
        ios_english.append(app)
        
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 6181
# Number of columns: 17

# %% [markdown]
# Desta forma, temos dois arquivos limpos, chamados de `android_english` e `ios_english`, com dados de *apps*
# apenas em inglês e sem redundâncias.
#
# Agora, iremos criar os *data sets* definitivos para a análise extraindo apenas os *apps* gratuitos, visto que nossa *startup*
# tem o foco neste tipo de aplicativo.
#
# Para tal, seguimos o procedimento de adicionar às novas listas `android_final` e `ios_final` apenas as linhas de aplicativos gratuitos.

# %%
android_final = []
ios_final = []

for app in android_english:
    # preço na coluna 7
    if app[7] == '0':
        android_final.append(app)
        
    
for app in ios_english:
    # preço na coluna 5
    if app[5] == '0':
        ios_final.append(app)

print(len(android_final), len(ios_final))
# Out:
# 8864 3220

# %% [markdown]
# ## Análise dos Dados
#
# Feita a limpeza dos *data sets*, nosso próximo objetivo é analisar os dados, determinando os tipos de aplicativos mais rentáveis para ambas App Store e Google Play. Para isto, é necessário que os gêneros sejam rentáveis em ambas as plataformas.
#
# A estratégia de validação a ser utilizada pela CVTech consiste em desenvolver uma versão mínima do app apenas para Google Play inicialmente. Tendo este *app* uma boa resposta dos usuários, serão implementadas melhorias para este, tornando-o um produto mais completo e, sendo o aplicativo rentável após seis meses, desenvolver-se-á a versão iOS deste *app*, subindo-o para a App Store.
#
# ### Gêneros com mais *apps*
#
# Para auxiliar nesta análise, criou-se a função `freq_table`, que tem como parâmetros *data set*, *index* e *percentage*, este com argumento padrão o valor lógico **True**. A função retorna um dicionário de frequências de determinada coluna (*index*) do *data set*, sendo o dicionário retornado em porcentagem se mantido o argumento padrão, e em números absolutos se mudado o valor lógico para **False**.
#
# Já a função `display_dict_decrescent` recebe um argumento do tipo dicionário e imprime a mesma em ordem decrescente.

# %%
def freq_table(dataset, index, percentage=True):
    total = 0
    table_absolutes = {}
    for row in dataset:
        total += 1
        data = row[index]
        if data in table_absolutes:
            table_absolutes[data] += 1
        else:
            table_absolutes[data] = 1       
    table_percentages = {}
    for key in table_absolutes:
        percentage = table_absolutes[key] / total * 100
        table_percentages[key] = percentage
    if percentage:
        return table_percentages
    else:
        return table_absolutes

def display_dict_decrescent(a_dict):
    table_display = []
    for key in a_dict:
        key_val_as_tuple = (a_dict[key], key)
        table_display.append(key_val_as_tuple)
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# Ao analisar os cabeçalhos dos *data sets*, identificamos que as colunas a serem utilizadas para identificar os gêneros dos *apps* são:
# - App Store: 12 - prime_genre
# - Google Play: 1 - category e 9 - genres
#
# Aplicando as funções nessas colunas, temos:

# %%
ios_freq = freq_table(ios_final, 12)
display_dict_decrescent(ios_freq)
print('\n\n')

android_freq1 = freq_table(android_final, 1)
display_dict_decrescent(android_freq1)
print('\n\n')

android_freq2 = freq_table(android_final, 9)
display_dict_decrescent(android_freq2)
print('\n\n')
# Out:
# Games : 58.13664596273293
# Entertainment : 7.888198757763975
# Photo & Video : 4.968944099378882
# Education : 3.6645962732919255
# Social Networking : 3.291925465838509
# Shopping : 2.608695652173913
# Utilities : 2.515527950310559
# Sports : 2.142857142857143
# Music : 2.049689440993789
# Health & Fitness : 2.018633540372671
# Productivity : 1.7391304347826086
# Lifestyle : 1.5838509316770186
# News : 1.3354037267080745
# Travel : 1.2422360248447204
# Finance : 1.1180124223602486
# Weather : 0.8695652173913043
# Food & Drink : 0.8074534161490683
# Reference : 0.5590062111801243
# Business : 0.5279503105590062
# Book : 0.43478260869565216
# Navigation : 0.18633540372670807
# Medical : 0.18633540372670807
# Catalogs : 0.12422360248447205
#
#
#
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# EVENTS : 0.7107400722021661
# PARENTING : 0.6543321299638989
# ART_AND_DESIGN : 0.6430505415162455
# COMICS : 0.6204873646209386
# BEAUTY : 0.5979241877256317
#
#
#
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# Libraries & Demo : 0.9363718411552346
# Auto & Vehicles : 0.9250902527075812
# Strategy : 0.9138086642599278
# House & Home : 0.8235559566787004
# Weather : 0.8009927797833934
# Events : 0.7107400722021661
# Adventure : 0.6768953068592057
# Comics : 0.6092057761732852
# Beauty : 0.5979241877256317
# Art & Design : 0.5979241877256317
# Parenting : 0.4963898916967509
# Card : 0.45126353790613716
# Casino : 0.42870036101083037
# Trivia : 0.41741877256317694
# Educational;Education : 0.39485559566787
# Board : 0.3835740072202166
# Educational : 0.3722924187725632
# Education;Education : 0.33844765342960287
# Word : 0.2594765342960289
# Casual;Pretend Play : 0.236913357400722
# Music : 0.2030685920577617
# Racing;Action & Adventure : 0.16922382671480143
# Puzzle;Brain Games : 0.16922382671480143
# Entertainment;Music & Video : 0.16922382671480143
# Casual;Brain Games : 0.13537906137184114
# Casual;Action & Adventure : 0.13537906137184114
# Arcade;Action & Adventure : 0.12409747292418773
# Action;Action & Adventure : 0.10153429602888085
# Educational;Pretend Play : 0.09025270758122744
# Simulation;Action & Adventure : 0.078971119133574
# Parenting;Education : 0.078971119133574
# Entertainment;Brain Games : 0.078971119133574
# Board;Brain Games : 0.078971119133574
# Parenting;Music & Video : 0.06768953068592057
# Educational;Brain Games : 0.06768953068592057
# Casual;Creativity : 0.06768953068592057
# Art & Design;Creativity : 0.06768953068592057
# Education;Pretend Play : 0.056407942238267145
# Role Playing;Pretend Play : 0.04512635379061372
# Education;Creativity : 0.04512635379061372
# Role Playing;Action & Adventure : 0.033844765342960284
# Puzzle;Action & Adventure : 0.033844765342960284
# Entertainment;Creativity : 0.033844765342960284
# Entertainment;Action & Adventure : 0.033844765342960284
# Educational;Creativity : 0.033844765342960284
# Educational;Action & Adventure : 0.033844765342960284
# Education;Music & Video : 0.033844765342960284
# Education;Brain Games : 0.033844765342960284
# Education;Action & Adventure : 0.033844765342960284
# Adventure;Action & Adventure : 0.033844765342960284
# Video Players & Editors;Music & Video : 0.02256317689530686
# Sports;Action & Adventure : 0.02256317689530686
# Simulation;Pretend Play : 0.02256317689530686
# Puzzle;Creativity : 0.02256317689530686
# Music;Music & Video : 0.02256317689530686
# Entertainment;Pretend Play : 0.02256317689530686
# Casual;Education : 0.02256317689530686
# Board;Action & Adventure : 0.02256317689530686
# Video Players & Editors;Creativity : 0.01128158844765343
# Trivia;Education : 0.01128158844765343
# Travel & Local;Action & Adventure : 0.01128158844765343
# Tools;Education : 0.01128158844765343
# Strategy;Education : 0.01128158844765343
# Strategy;Creativity : 0.01128158844765343
# Strategy;Action & Adventure : 0.01128158844765343
# Simulation;Education : 0.01128158844765343
# Role Playing;Brain Games : 0.01128158844765343
# Racing;Pretend Play : 0.01128158844765343
# Puzzle;Education : 0.01128158844765343
# Parenting;Brain Games : 0.01128158844765343
# Music & Audio;Music & Video : 0.01128158844765343
# Lifestyle;Pretend Play : 0.01128158844765343
# Lifestyle;Education : 0.01128158844765343
# Health & Fitness;Education : 0.01128158844765343
# Health & Fitness;Action & Adventure : 0.01128158844765343
# Entertainment;Education : 0.01128158844765343
# Communication;Creativity : 0.01128158844765343
# Comics;Creativity : 0.01128158844765343
# Casual;Music & Video : 0.01128158844765343
# Card;Action & Adventure : 0.01128158844765343
# Books & Reference;Education : 0.01128158844765343
# Art & Design;Pretend Play : 0.01128158844765343
# Art & Design;Action & Adventure : 0.01128158844765343
# Arcade;Pretend Play : 0.01128158844765343
# Adventure;Education : 0.01128158844765343

# %% [markdown]
# Vê-se que, na App Store, os aplicativos de Jogos dominam amplamente o mercado, com mais de 58% dos aplicativos
# grátis e em inglês. Também nota-se que aplicativos relacionados a utilidades, como as categorias *Utilities* e *Productivity*,
# são bem menos frequentes que aplicativos relacionados a lazer e entretenimento, como *Entertainment*, *Photo & Video* e *Social
# Networking*.
#
# Já na coluna *Category* dos *apps* grátis e em inglês da Google Play, mais de 18% dos aplicativos são
# categorizados como *Family*, o que, após breve pesquisa, concluiu-se abranger em sua maioria jogos para crianças.
# Junto aos mais de 9% da segunda categoria mais frequente *Games*, vemos que o padrão da mais alta popularidade de jogos
# visto na App Store se repete na Google Play, porém de maneira bem mais equilibrada. Nesta plataforma, em contrário àquela,
# os aplicativos de produtividade são bem frequentes, representando mais de 8% na categoria *Tools* (terceira mais frequente), mais de 4% em *Business* e quase 4% em *Lifestyle*, por exemplo.
#
# Analizando a coluna *Genres* dos *apps* grátis e em inglês da Google Play, nota-se que o primeiro colocado é a categoria
# *Tools*, com quase 8,5%. Percebe-se que essa porcentagem é bem menos que a líder na categoria *Category*. Após maior análise,
# nota-se que a coluna *Genres* tem bem mais categorias que a coluna *Category*, sub-dividindo as categorias em vários gêneros.
#
# Analisando os dados adquiridos, tem-se como ideia inicial a elaboração de um jogo, dada sua grande popularidade na App Store
# e que se repete, em menor escala, na Google Play.

# %% [markdown]
# ### Gêneros mais populares
#
# Uma outra informação que nos é útil é saber que gêneros são os mais populares dentre os observados. Para avaliar isto, devemos olhar a quantidade média de *downloads* por gênero, diferentemente do analisado anteriormente, que leva em consideração a quantidade de *apps* de determinado gênero face o total de cada plataforma.
#
# No *data set* da Google Play, podemos observar a presença da coluna relativa a instalações, chamada de *Installs* (número 5). Já no *data set* da App Store, não existe coluna relativa a instalações, então utilizamos a coluna *rating_count_tot* (número 6), que mostra o total de avaliações de usuários do aplicativo.
#
# Vale relembrar que estamos utilizando as colunas *prime_genre* (coluna 12) do *data set* da App Store e *Category* (coluna 1) do *data set* da Google Play.
#
# Para desenvolver tal estudo, criaremos a função `category_sum`, que tem os parâmetros *dataset*, *index* e *variable*. Esta função, ao receber uma determinado *data set* no parâmetro quase homônimo, cria uma dicionário que tem como *key* as strings da coluna *index* do *data set* e, como *values*, a soma de seus valores na coluna *variable* convertidos para números *float*.
#
# Outra função criada é a `category_avg`, que tem o funcionamento semelhante à supracitada, mas retorna em seus *values* a média dos valores.

# %%
def category_sum(dataset, index, variable):
    a_dict = {}
    for row in dataset:
        key = row[index]
        value = row[variable]
        value = value.replace('+','')
        value = float(value.replace(',',''))
        if key in a_dict:
            a_dict[key] += value
        else:
            a_dict[key] = value
    return a_dict
        
def category_avg(dataset, index, variable):
    a_dict = {}
    count_dict = {}
    for row in dataset:
        key = row[index]
        value = row[variable]
        value = value.replace('+','')
        value = float(value.replace(',',''))
        if key in a_dict:                    # tem que estar em count_dict também, mas como é impossível não estar dada
            count_dict[key] += 1             # a programação, não foi incluída esta condição.
            a_dict[key] = a_dict[key] + value
        else:
            count_dict[key] = 1
            a_dict[key] = value
    for key in a_dict:
        a_dict[key] /= count_dict[key]
    return a_dict

# %% [markdown]
# Notam-se nas funções a substituição dos caracteres '+' e ',' por uma string vazia ''. Isto é foi efetuado devido ao *data set* da Google Play ter um problema a ser resulvido. Visualizando a tabela de frequências da coluna *Installs* do *data set*, vemos que os termos possuem caracteres não numéricos, mais especificamente '+' e ','. Deste modo, a conversão para float para os cálculos nas funções `category_sum` e `category_avg` seriam impossibilitados sem este cuidado. Este fato é confirmado a seguir, utilizando a nova função `display_table`.

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])
        
display_table(android_final, 5)
# Out:
# 1,000,000+ : 15.726534296028879
# 100,000+ : 11.552346570397113
# 10,000,000+ : 10.548285198555957
# 10,000+ : 10.198555956678701
# 1,000+ : 8.393501805054152
# 100+ : 6.915613718411552
# 5,000,000+ : 6.825361010830325
# 500,000+ : 5.561823104693141
# 50,000+ : 4.7721119133574
# 5,000+ : 4.512635379061372
# 10+ : 3.5424187725631766
# 500+ : 3.2490974729241873
# 50,000,000+ : 2.3014440433213
# 100,000,000+ : 2.1322202166064983
# 50+ : 1.917870036101083
# 5+ : 0.78971119133574
# 1+ : 0.5076714801444043
# 500,000,000+ : 0.2707581227436823
# 1,000,000,000+ : 0.22563176895306858
# 0+ : 0.04512635379061372
# 0 : 0.01128158844765343

# %% [markdown]
# Vemos também que os dados não são exatos como na categoria *rating_count_tot* do *data set* da App Store, mas sim estimados. Como nosso propósito nesta análise não é saber exatamente o número de usuários de cada gênero de *app*, mas sim quais deles são os mais utilizados, podemos considerar, por exemplo, que 1,000,000+ de instalações é apenas 1.000.000 de instalações, e assim por diante. É notado que esta prática pode nos levar a conclusões falsas do que queremos, visto que um *app* com 100.000.000 seria contabilizado da mesma maneira que um de 499.000.000. Porém, como o limite superior do nosso espectro de análise, que é 1.000.000.000 de instalações, possui apenas aproximadamente 0,2% dos aplicativos, o nível dessa imprecisão é diminuido.
#
# Ratificada a abordagem a ser efetuada, ela foi posta em prática. Utilizando a função `str.replace(old, new)`, podemos substituir uma string de caracteres por uma outra. Desta maneira, foi feita a substituição da string '+' e da string ',' por '', que é uma string vazia. Este procedimento é feito a seguir, criando uma função :
#
# Aplicando ambas as funções nos  *data sets* da App Store e da Google Play e imprimindo o resultado em ordem decrescente utilizando a função `display_dict_decrescent`, temos:

# %%
ios_category_sum = category_sum(ios_final, 12, 6)
print('Soma de quantidade de avaliações de usuários por gênero na App Store:')
display_dict_decrescent(ios_category_sum)
print('\n\n')

android_category_sum = category_sum(android_final, 1, 5)
print('Instalações por gênero na Google Play:')
display_dict_decrescent(android_category_sum)
print('\n\n')

ios_category_avg = category_avg(ios_final, 12, 6)
print('Média de quantidade de avaliações de usuários por aplicativo do gênero na App Store:')
display_dict_decrescent(ios_category_avg)
print('\n\n')

android_category_avg = category_avg(android_final, 1, 5)
print('Média de instalações por aplicativo do gênero na Google Play:')
display_dict_decrescent(android_category_avg)
print('\n\n')
# Out:
# Soma de quantidade de avaliações de usuários por gênero na App Store:
# Games : 42705795.0
# Social Networking : 7584125.0
# Photo & Video : 4550647.0
# Music : 3783551.0
# Entertainment : 3563577.0
# Shopping : 2261254.0
# Sports : 1587614.0
# Health & Fitness : 1514371.0
# Utilities : 1513441.0
# Weather : 1463837.0
# Reference : 1348958.0
# Productivity : 1177591.0
# Finance : 1132846.0
# Travel : 1129752.0
# News : 913665.0
# Food & Drink : 866682.0
# Lifestyle : 840774.0
# Education : 826470.0
# Book : 556619.0
# Navigation : 516542.0
# Business : 127349.0
# Catalogs : 16016.0
# Medical : 3672.0
#
#
#
# Instalações por gênero na Google Play:
# GAME : 13436869450.0
# COMMUNICATION : 11036906201.0
# TOOLS : 8101043474.0
# FAMILY : 6193895690.0
# PRODUCTIVITY : 5791629314.0
# SOCIAL : 5487861902.0
# PHOTOGRAPHY : 4656268815.0
# VIDEO_PLAYERS : 3931731720.0
# TRAVEL_AND_LOCAL : 2894704086.0
# NEWS_AND_MAGAZINES : 2368196260.0
# BOOKS_AND_REFERENCE : 1665884260.0
# PERSONALIZATION : 1529235888.0
# SHOPPING : 1400338585.0
# HEALTH_AND_FITNESS : 1143548402.0
# SPORTS : 1095230683.0
# ENTERTAINMENT : 989460000.0
# BUSINESS : 696902090.0
# MAPS_AND_NAVIGATION : 503060780.0
# LIFESTYLE : 497484429.0
# FINANCE : 455163132.0
# WEATHER : 360288520.0
# FOOD_AND_DRINK : 211738751.0
# EDUCATION : 188850000.0
# DATING : 140914757.0
# ART_AND_DESIGN : 113221100.0
# HOUSE_AND_HOME : 97202461.0
# AUTO_AND_VEHICLES : 53080061.0
# LIBRARIES_AND_DEMO : 52995810.0
# COMICS : 44971150.0
# MEDICAL : 37732344.0
# PARENTING : 31471010.0
# BEAUTY : 27197050.0
# EVENTS : 15973160.0
#
#
#
# Média de quantidade de avaliações de usuários por aplicativo do gênero na App Store:
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 71548.34905660378
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 39758.5
# Food & Drink : 33333.92307692308
# Finance : 31467.944444444445
# Photo & Video : 28441.54375
# Travel : 28243.8
# Shopping : 26919.690476190477
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22812.92467948718
# News : 21248.023255813954
# Productivity : 21028.410714285714
# Utilities : 18684.456790123455
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Business : 7491.117647058823
# Education : 7003.983050847458
# Catalogs : 4004.0
# Medical : 612.0
#
#
#
# Média de instalações por aplicativo do gênero na Google Play:
# COMMUNICATION : 38456119.167247385
# VIDEO_PLAYERS : 24727872.452830188
# SOCIAL : 23253652.127118643
# PHOTOGRAPHY : 17840110.40229885
# PRODUCTIVITY : 16787331.344927534
# GAME : 15588015.603248259
# TRAVEL_AND_LOCAL : 13984077.710144928
# ENTERTAINMENT : 11640705.88235294
# TOOLS : 10801391.298666667
# NEWS_AND_MAGAZINES : 9549178.467741935
# BOOKS_AND_REFERENCE : 8767811.894736841
# SHOPPING : 7036877.311557789
# PERSONALIZATION : 5201482.6122448975
# WEATHER : 5074486.197183099
# HEALTH_AND_FITNESS : 4188821.9853479853
# MAPS_AND_NAVIGATION : 4056941.7741935486
# FAMILY : 3695641.8198090694
# SPORTS : 3638640.1428571427
# ART_AND_DESIGN : 1986335.0877192982
# FOOD_AND_DRINK : 1924897.7363636363
# EDUCATION : 1833495.145631068
# BUSINESS : 1712290.1474201474
# LIFESTYLE : 1437816.2687861272
# FINANCE : 1387692.475609756
# HOUSE_AND_HOME : 1331540.5616438356
# DATING : 854028.8303030303
# COMICS : 817657.2727272727
# AUTO_AND_VEHICLES : 647317.8170731707
# LIBRARIES_AND_DEMO : 638503.734939759
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120550.61980830671

# %% [markdown]
# ### Ajustes na Análise
#
# Ao observamos os resultados relativos às respectivas médias calculadas da App Store e da Google Play, notamos fatos interessantes.
#
# Os cinco gêneros de *apps* com maiores médias de quantidade de avaliações de usuários por aplicativo na App Store são *Navigation*, *Reference*, *Social Networking*, *Music* e *Weather*.
#
# Destes, podemos ver que o gênero com maior número de aplicativos relativos ao total da plataforma é a *Social Networking*, com um pouco mais de 3%. O gênero *Navigation*, líder neste quesito de média, tem menos de 0,2% de aplicativos em relação ao total. Diante disto, veio o questionamento acerca do porquê destas categorias, que teoricamente são usados por muitos, não serem um nicho tão atrativo para outros desenvolvedores.
#
# Pensou-se na hipótese de que alguns indicativos poderiam estar sendo muito influenciados por aplicativos que monopolizam tal categoria. Para evitar dados deturpados por essa possibilidade, resolveu-se repetir a análise excluindo aplicativos com mais de 100.000.000 instalações na Google Play, o que representam *apps* muito difíceis de se competir contra, principalmente levando-se em consideração o fato de esta pesquisa ser para o primeiro aplicativo da CVTech.
#
# Baseado neste pensamento, criamos um novo *data set* para cada plataforma, contendo apenas os aplicativos com um máximo de 10.000.000 de instalações na Google Play e de 50.000 avaliações na App Store, visto que estes números cumpririam muito bem as expectativas da *startup* para seu primeiro aplicativo.

# %%
study_ratings = {}
for app in ios_final:
    name = app[2]
    rating_count = float(app[6])
    study_ratings[name] = rating_count
    
display_dict_decrescent(study_ratings)
# Out:
# Facebook : 2974676.0
# Instagram : 2161558.0
# Clash of Clans : 2130805.0
# Temple Run : 1724546.0
# Pandora - Music & Radio : 1126879.0
# Pinterest : 1061624.0
# Bible : 985920.0
# Candy Crush Saga : 961794.0
# Spotify Music : 878563.0
# Angry Birds : 824451.0
# Subway Surfers : 706110.0
# Solitaire : 679055.0
# CSR Racing : 677247.0
# Crossy Road - Endless Arcade Hopper : 669079.0
# Injustice: Gods Among Us : 612532.0
# Hay Day : 567344.0
# PAC-MAN : 508808.0
# Calorie Counter & Diet Tracker by MyFitnessPal : 507706.0
# DragonVale : 503230.0
# The Weather Channel: Forecast, Radar & Alerts : 495626.0
# Head Soccer : 481564.0
# Google – Search made just for mobile : 479440.0
# Despicable Me: Minion Rush : 464312.0
# The Sims™ FreePlay : 446880.0
# Google Earth : 446185.0
# Sonic Dash : 418033.0
# Groupon - Deals, Coupons & Discount Shopping App : 417779.0
# 8 Ball Pool™ : 416736.0
# Tiny Tower - Free City Building : 414803.0
# Jetpack Joyride : 405647.0
# Bike Race - Top Motorcycle Racing Games : 405007.0
# Shazam - Discover music, artists, videos & lyrics : 402925.0
# Kim Kardashian: Hollywood : 397730.0
# Trivia Crack : 393469.0
# WordBrain : 391401.0
# Sniper 3D Assassin: Shoot to Kill Gun Game : 386521.0
# Flow Free : 373857.0
# Lose It! – Weight Loss Program and Calorie Counter : 373835.0
# Skype for iPhone : 373519.0
# Geometry Dash Lite : 370370.0
# ▻Sudoku : 359832.0
# Twitter : 354058.0
# Messenger : 351466.0
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046.0
# Zillow Real Estate - Homes for Sale & for Rent : 342969.0
# Tumblr : 334293.0
# Fruit Ninja® : 327025.0
# Snapchat : 323905.0
# Netflix : 308844.0
# Starbucks : 303856.0
# Pixel Gun 3D : 301182.0
# Temple Run 2 : 295211.0
# My Horse : 293857.0
# iHeartRadio – Free Music & Radio Stations : 293228.0
# Fandango Movies - Times + Tickets : 291787.0
# ESPN: Get scores, news, alerts & watch live sports : 290996.0
# WhatsApp Messenger : 287589.0
# Word Cookies! : 287095.0
# YouTube - Watch Videos, Music, and Live Streams : 278166.0
# Dragon City Mobile : 277268.0
# The Simpsons™: Tapped Out : 274501.0
# Plants vs. Zombies™ 2 : 267394.0
# Clash Royale : 266921.0
# eBay: Best App to Buy, Sell, Save! Online Shopping : 262241.0
# Kik : 260965.0
# Domino's Pizza USA : 258624.0
# Pokémon GO : 257627.0
# CSR Racing 2 : 257100.0
# Star Wars™: Commander : 253448.0
# Kindle – Read eBooks, Magazines & Textbooks : 252076.0
# Colorfy: Coloring Book for Adults : 247809.0
# Boom Beach : 241929.0
# MARVEL Contest of Champions : 233599.0
# Chase Mobile℠ : 233270.0
# Mint: Personal Finance, Budget, Bills & Money : 232940.0
# MADDEN NFL Mobile : 230289.0
# Yelp - Nearby Restaurants, Shopping & Services : 223885.0
# Bejeweled Blitz : 221002.0
# Can You Escape : 218024.0
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 208648.0
# Dictionary.com Dictionary & Thesaurus : 200047.0
# Fallout Shelter : 199396.0
# SimCity BuildIt : 198338.0
# Real Basketball : 198050.0
# Yahoo Fantasy Sports : 190670.0
# WeatherBug - Local Weather, Radar, Maps, Alerts : 188583.0
# Asphalt 8: Airborne : 188568.0
# Magic Jigsaw Puzzles : 187666.0
# Farm Heroes Saga : 187579.0
# Beer Pong Game : 187315.0
# Glow Hockey 2 FREE : 186653.0
# Pictoword: Fun 2 Pics Guess What's the Word Trivia : 186089.0
# ROBLOX : 183621.0
# IMDb Movies & TV - Trailers and Showtimes : 183425.0
# Bejeweled Classic : 183259.0
# Daily Celebrity Crossword : 181384.0
# AdVenture Capitalist : 181359.0
# Blackjack by MobilityWare : 180087.0
# Call of Duty®: Heroes : 179416.0
# Deer Hunter Classic : 179111.0
# ooVoo – Free Video Call, Text and Voice : 177501.0
# Agar.io : 176514.0
# Piano Tiles (Don't Tap The White Tile) : 172686.0
# TRUTH or DARE!!! - FREE : 171055.0
# Angry Birds Rio : 170843.0
# The Secret Society® - Hidden Mystery : 168674.0
# TextNow - Unlimited Text + Calls : 164963.0
# Real Racing 3 : 164483.0
# Highway Rider : 164377.0
# Viber Messenger – Text & Call : 164249.0
# Duolingo - Learn Spanish, French and more : 162701.0
# Evernote - stay organized : 161065.0
# Words with Friends – Best Word Game : 160668.0
# WatchESPN : 159735.0
# Bowmasters - Top Multiplayer Bowman Archery Game : 159323.0
# aa : 158845.0
# 2048 : 157882.0
# Episode - Choose Your Story : 155903.0
# Google Maps - Navigation & Transit : 154911.0
# Dumb Ways to Die : 151559.0
# MyRadar NOAA Weather Radar Forecast : 150158.0
# Jurassic World™: The Game : 149138.0
# The Masters Tournament : 148160.0
# GasBuddy : 145549.0
# Color Switch : 145043.0
# AccuWeather - Weather for Life : 144214.0
# Tinder : 143040.0
# Wish - Shopping Made Fun : 141960.0
# Iron Force : 141634.0
# Racing Penguin Free - Top Flying and Diving Game : 141224.0
# Two Dots : 139486.0
# Jigsaw Puzzle : 138726.0
# Yahoo Sports - Teams, Scores, News & Highlights : 137951.0
# Summoners War : 137122.0
# Weight Watchers : 136833.0
# Gmail - email by Google: secure, fast & organized : 135962.0
# SoundCloud - Music & Audio : 135744.0
# Sniper Shooter: Gun Shooting Games : 134080.0
# Candy Crush Soda Saga : 133394.0
# Fox News : 132703.0
# Magic Piano by Smule : 131695.0
# shopkick - Shopping Rewards & Discounts : 130823.0
# My Singing Monsters : 130519.0
# Flashlight Ⓞ : 130450.0
# Spider Solitaire Free by MobilityWare : 128739.0
# My Verizon : 126948.0
# Amazon App: shop, scan, compare, and read reviews : 126312.0
# Smash Hit : 126233.0
# ▻Solitaire : 124618.0
# My Talking Tom : 123859.0
# Pic Collage - Picture Editor & Photo Collage Maker : 123433.0
# Funimate video editor: add cool effects to videos : 123268.0
# iTranslate - Language Translator & Dictionary : 123215.0
# Guess My Age  Math Magic : 123190.0
# Clumsy Ninja : 123032.0
# Tetris® Blitz : 122868.0
# Star Wars™: Galaxy of Heroes : 122260.0
# Bubble Mania™ : 122081.0
# Bank of America - Mobile Banking : 119773.0
# PayPal - Send and request money safely : 119487.0
# Smule Sing! : 119316.0
# Mad Libs : 117889.0
# Geometry Dash Meltdown : 117470.0
# Beat the Boss 2 : 117338.0
# Village Life: Love, Marriage and Babies : 116620.0
# MORTAL KOMBAT X : 114475.0
# Sky Burger - Build & Match Food Free : 114096.0
# Big Fish Casino – Best Vegas Slot Machines & Games : 113959.0
# OpenTable - Restaurant Reservations : 113936.0
# Yahoo Mail - Keeps You Organized! : 113709.0
# CNN: Breaking US & World News, Live Video : 112886.0
# Followers - Social Analytics For Instagram : 112778.0
# Yahoo Weather : 112603.0
# Monster Legends RPG - War, Fight & Heroes Game : 111579.0
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 110420.0
# Fairway Solitaire Blast : 110062.0
# Twitch : 109549.0
# Allrecipes Dinner Spinner : 109349.0
# Angry Birds 2 : 109104.0
# myAT&T : 108507.0
# Hill Climb Racing : 108183.0
# Target : 108131.0
# Game of War - Fire Age : 107916.0
# slither.io : 107817.0
# Cooking Fever : 107797.0
# Angry Birds Transformers : 106434.0
# ⋆Solitaire : 106398.0
# Amazon Music : 106235.0
# musical.ly - your video social network : 105429.0
# Audible – audio books, original series & podcasts : 105274.0
# Sleep Cycle alarm clock : 104539.0
# ZigZag : 104502.0
# Family Guy: The Quest for Stuff : 104060.0
# Zappos: shop shoes & clothes, fast free shipping : 103655.0
# Credit Karma: Free Credit Scores, Reports & Alerts : 101679.0
# DoubleDown Casino & Slots  – Vegas Slot Machines! : 101599.0
# Action Movie FX : 101222.0
# Text Free: Free Texting + Calling + MMS : 100477.0
# MLB.com Home Run Derby 17 : 100035.0
# The Calculator - Free and Easy Calculating! : 99244.0
# Shadow Fight 2 : 99206.0
# Voice Changer Plus : 98777.0
# iFunny :) : 98344.0
# The CW : 97368.0
# War Robots : 97122.0
# MeetMe - Chat and Meet New People : 97072.0
# Lumosity - Brain Training : 96534.0
# Angry Birds Space : 95892.0
# Photo Collage Maker & Photo Editor - Live Collage : 93781.0
# PewDiePie's Tuber Simulator : 90851.0
# Fitbit : 90496.0
# We Heart It - Fashion, wallpapers, quotes, tattoos : 90414.0
# Vine Camera : 90355.0
# Angry Birds HD : 89110.0
# Walgreens – Pharmacy, Photo, Coupons and Shopping : 88885.0
# Google Photos - unlimited photo and video storage : 88742.0
# The Moron Test : 88613.0
# Super Mario Run : 87958.0
# Tap Titans : 87898.0
# InsTrack for Instagram - Analytics Plus More : 85535.0
# Score! Hero : 85395.0
# Angry Birds Epic RPG : 84680.0
# Color Therapy Adult Coloring Book for Adults : 84062.0
# Hungry Shark Evolution : 83784.0
# SoundHound Song Search & Music Player : 82602.0
# Candy Blast Mania : 81648.0
# Godus : 81311.0
# DIRECTV : 81006.0
# Township : 80801.0
# Best Buy : 80424.0
# 4 Pics 1 Word : 80308.0
# Blackbox - think outside the box : 80058.0
# Flipagram : 79905.0
# Egg, Inc. : 79074.0
# DEAD TRIGGER : 78918.0
# ABC – Watch Live TV & Stream Full Episodes : 78890.0
# Block Craft 3D: Building Simulator Game For Free : 78412.0
# Daddy Long Legs : 76622.0
# Nyan Cat: Lost In Space : 76392.0
# Toy Blast : 75822.0
# Angry Birds Go! : 75793.0
# Angry Birds Seasons HD : 75714.0
# Tango - Free Video Call, Voice and Chat : 75412.0
# Covet Fashion - The Game for Dresses & Shopping : 75034.0
# QuizUp™ : 72989.0
# Xbox : 72187.0
# LinkedIn : 71856.0
# Bejeweled Classic HD : 70926.0
# Walmart: Free 2-Day Shipping,* Easy Store Shopping : 70286.0
# Angry Birds Rio HD : 70122.0
# Trigger Fist : 69624.0
# Slots - Pharaoh's Way : 69610.0
# Stack : 69368.0
# UNO ™ & Friends : 68911.0
# Bloons TD Battles : 67861.0
# Reddit Official App: All That's Trending and Viral : 67560.0
# Dream League Soccer 2017 : 66004.0
# Solitaire· : 66002.0
# Ace Fishing: Wild Catch : 65831.0
# OverDrive – Library eBooks and Audiobooks : 65450.0
# MY LITTLE PONY: Magic Princess Quests : 65201.0
# LINE: Disney Tsum Tsum : 65155.0
# Speedtest by Ookla : 65016.0
# ESPN Fantasy Football Baseball Basketball Hockey : 64925.0
# MARVEL Spider-Man Unlimited : 64586.0
# Google Docs : 64259.0
# Criminal Case : 63291.0
# WordBubbles! : 62061.0
# USA TODAY : 61724.0
# Match™ - #1 Dating App. : 60659.0
# Happy Wheels : 60601.0
# Countdown‼ (Event Reminders and Timer) : 60490.0
# Cascade: Fun Spin and Match Puzzle Game : 60488.0
# Flight Pilot Simulator 3D: Flying Game For Free : 60360.0
# Bowling King : 60271.0
# Redbox : 60236.0
# Skype for iPad : 60163.0
# CBS Sports App - Sports Scores, News, Stats, Watch : 59639.0
# Google Drive - free online storage : 59255.0
# Gummy Drop! – A Match 3 Puzzle Game : 59158.0
# Viva™ Slots Las Vegas Classic Casino Games : 58738.0
# Logos Quiz -Guess the most famous brands, new fun! : 58640.0
# Elevate - Brain Training and Games : 58092.0
# FOX Sports Mobile : 57500.0
# OfferUp - Buy. Sell. Simple. : 57348.0
# Bingo!™ : 56852.0
# Talking Tom Cat 2 for iPad : 56399.0
# TripAdvisor Hotels Flights Restaurants : 56194.0
# Hulu: Watch TV Shows & Stream the Latest Movies : 56170.0
# Capital One Mobile : 56110.0
# WordWhizzle : 56054.0
# NBC – Watch Now and Stream Full TV Episodes : 55950.0
# My Boo - Virtual Pet with Mini Games for Kids : 55783.0
# Google Chrome – The Fast and Secure Web Browser : 55750.0
# Racing Rivals : 55548.0
# Emoji> : 55338.0
# Apple Store : 55171.0
# Piano Tiles 2™(Don't Tap The White Tile 2) : 55077.0
# Kendall and Kylie : 55011.0
# Shop Savvy Barcode Scanner - Price Compare & Deals : 54630.0
# My Talking Angela : 54549.0
# Alarm Clock HD Free - Digital Alarm Clock Display : 54496.0
# Mixgram - Picture Collage Maker - Pic Photo Editor : 54282.0
# 2016 U.S. Open Golf Championship : 54192.0
# Dictionary.com Dictionary & Thesaurus for iPad : 54175.0
# Period Tracker Lite : 53620.0
# 1010! : 53496.0
# NYTimes Crossword - Daily Word Puzzle Game : 53465.0
# Evil Apples: A Filthy Adult Card & Party Game : 53415.0
# WGT Golf Game by Topgolf : 53285.0
# Smashy Road: Wanted : 53162.0
# Cookie Jam : 52831.0
# POF - Best Dating App for Conversations : 52642.0
# Shutterfly: Prints, Photo Books, Cards Made Easy : 51427.0
# Pic Jointer – Photo Collage, Camera Effects Editor : 51330.0
# Frozen Free Fall : 50593.0
# PINK Nation : 49816.0
# WordWhizzle Search : 49635.0
# Dropbox : 49578.0
# Timehop : 49510.0
# Uber : 49466.0
# Weather Underground: Custom Forecast & Local Radar : 49192.0
# Sonos Controller : 48905.0
# Citi Mobile® : 48822.0
# Jelly Jump : 48694.0
# ABC News - US & World News + Live Video : 48407.0
# Close Up Pics Quiz - Guess the Word Trivia Games : 48032.0
# Microsoft Word : 47999.0
# Castle Clash: Brave Squads : 47963.0
# Mahjong Journey® : 47949.0
# HOOKED - Chat Stories : 47829.0
# Calculator Pro for iPad Free - Smart Calculator : 47803.0
# DIRECTV App for iPad : 47506.0
# Alice in the Mirrors of Albion: Hidden object game : 47382.0
# NBC Sports : 47172.0
# Lyft : 46922.0
# Super Stickman Golf 2 : 46859.0
# Gangstar Vegas : 46705.0
# Seekers Notes: Hidden Mystery : 46384.0
# Fit Brains Trainer : 46363.0
# NOAA Weather Radar - Weather Forecast & HD Radar : 45696.0
# Tricky Test 2™: Genius Brain? : 45578.0
# Color Pop Effects - Photo Editor & Picture Editing : 45320.0
# Modern Combat 5 : The Multiplayer eSports Shooter : 45270.0
# Gardenscapes - New Acres : 45227.0
# Ibotta: Cash Back App, Grocery Coupons & Shopping : 44313.0
# Wooden Block Puzzle - Wood jigsaw fit 1010 matrix : 44237.0
# Find My Family, Friends & iPhone - Life360 Locator : 43877.0
# CSR Classics : 43770.0
# NBA : 43682.0
# Amazon Prime Video : 43667.0
# Soccer Stars™ : 43216.0
# Wells Fargo Mobile : 43064.0
# Flippy Bottle Extreme! - Marker Flip Tricky 2K16 : 42435.0
# Hangman. : 42316.0
# Billionaire – Business Capitalist Tycoon! : 42058.0
# World of Tanks Blitz : 41729.0
# Pearl's Peril - Hidden Object Adventures : 41428.0
# Real Steel World Robot Boxing : 41277.0
# Blitz Brigade: Multiplayer FPS shooter online! : 41266.0
# Panda Pop : 41214.0
# The Sandbox - Building & Crafting a Pixel World! : 41108.0
# Disney Emoji Blitz : 41036.0
# NBA LIVE Mobile Basketball : 40619.0
# Photo Grid - photo collage maker & photo editor : 40531.0
# YAHTZEE® With Buddies: The Classic Dice Game : 40446.0
# Jigsaw Puzzle Collection HD : 40227.0
# Whisper - Share, Express, Meet : 39819.0
# iSwap Faces LITE : 39722.0
# ESPN Tournament Challenge : 39642.0
# Microsoft OneNote : 39638.0
# Angry Birds Space HD : 39502.0
# Photo Editor by Aviary : 39501.0
# MOLDIV - Photo Editor, Collage & Beauty Camera : 39501.0
# CBS Full Episodes and Live TV : 39436.0
# FOX NOW - Watch Full Episodes and Stream Live TV : 39391.0
# Fishdom : 39217.0
# Indeed Job Search : 38681.0
# Disney Crossy Road : 38571.0
# letgo: Buy & Sell Second Hand Stuff : 38424.0
# Zombie Frontier 3 – Top Zombie Shooting Game : 38159.0
# Lep's World Free - platformer games : 38075.0
# Bitmoji - Your Personal Emoji : 37972.0
# Best Fiends : 37584.0
# 2016 US Open Tennis Championships : 37522.0
# Hidden City®: Mystery of Shadows : 37304.0
# Calculator‰ : 36879.0
# Unison League : 36414.0
# Hangouts : 36404.0
# Gin Rummy Plus - Multiplayer Online Card Game : 36355.0
# CVS Pharmacy : 35981.0
# Flashlight ！ : 35769.0
# Angry Birds POP! - Bubble Shooter : 35711.0
# Weather Live Free - Weather Forecast & Alerts : 35702.0
# Timberman : 35587.0
# Yu-Gi-Oh! Duel Links : 35570.0
# ClassDojo : 35440.0
# Fishing Kings Free+ : 35058.0
# Need for Speed™ No Limits : 34998.0
# Hearthstone : 34694.0
# LINE PLAY - Your Avatar World : 34677.0
# Photo Lab: Picture Editor, effects & fun face app : 34585.0
# WeChat : 34584.0
# Victoria’s Secret – The Sexiest Bras & Lingerie : 34507.0
# Badoo - Meet New People, Chat, Socialize. : 34428.0
# Chase Mobile : 34322.0
# Angry Birds Star Wars : 34138.0
# Dragon Mania Legends: Dragon Breeding Game : 34039.0
# Nike+ Training Club - Workouts & Fitness Plans : 33969.0
# Rookie Cam - Photo Editor & Filter Camera : 33921.0
# Hill Climb Racing 2 : 33854.0
# Cooking Dash™ : 33808.0
# Angry Birds Star Wars II : 33724.0
# Choices: Stories You Play : 33698.0
# Egg! : 33407.0
# Mr Jump : 33282.0
# NBC News : 32881.0
# Microsoft Outlook - email and calendar : 32807.0
# Talking Angela for iPad : 32763.0
# FotoRus -Camera & Photo Editor & Pic Collage Maker : 32558.0
# Jenga : 32527.0
# Hotspot Shield Free VPN Proxy & Wi-Fi Privacy : 32499.0
# Into the Dead : 32492.0
# Candy Crush Jelly Saga : 32395.0
# HotelTonight - Great Deals on Last Minute Hotels : 32341.0
# Solitaire TriPeaks: Classic Card Game : 32215.0
# Arrow Ambush : 32020.0
# Fun Run 2 - Multiplayer Race : 31981.0
# Stick Hero : 31727.0
# Zombie Tsunami : 31311.0
# Hotels & Vacation Rentals by Booking.com : 31261.0
# Neko Atsume: Kitty Collector : 31219.0
# Recolor - Coloring Book : 31180.0
# Talking Ben the Dog for iPad : 31116.0
# 100 Balls : 30967.0
# Bandsintown Concerts : 30845.0
# Crazy Kitchen : 30704.0
# Rolling Sky : 30670.0
# Southwest Airlines : 30552.0
# Etsy: Shop Handmade, Vintage & Creative Goods : 30434.0
# WWE Immortals : 29918.0
# World Chef: Restaurant & Cooking Game : 29886.0
# Dog Simulator 2015 : 29817.0
# Twist : 29548.0
# Talking Tom Cat for iPad : 29492.0
# Blossom Blast Saga - Fun Flower Match & Grow Game : 29475.0
# Documents 6 - File manager, PDF reader and browser : 29110.0
# HuffPost - News, Politics & Entertainment : 29107.0
# Trials Frontier : 29090.0
# PicsArt Photo Studio: Collage Maker & Pic Editor : 29078.0
# Megapolis : 28902.0
# Extreme Car Driving Simulator Free : 28900.0
# Pop the Lock : 28754.0
# Quik – GoPro Video Editor to edit clips with music : 28654.0
# Followers + for Instagram - Follower Analytics : 28633.0
# Karaoke - Sing Karaoke, Unlimited Songs! : 28606.0
# YouTube Kids : 28560.0
# Block! Hexa Puzzle : 28524.0
# Dude Perfect 2 : 28361.0
# GroupMe : 28260.0
# Basketball Stars™ : 28216.0
# Splice - Video Editor + Movie Maker by GoPro : 28189.0
# FINAL FANTASY BRAVE EXVIUS : 28187.0
# Doodle Jump FREE - BE WARNED: Insanely addictive : 28153.0
# Truecaller - Spam Identification & Block : 27791.0
# Browser and File Manager for Documents : 27750.0
# Batman: Arkham Origins : 27738.0
# Tom's Love Letters : 27711.0
# Marco Polo Video Walkie Talkie : 27662.0
# Make It Rain: The Love of Money : 27556.0
# Plant Nanny - Water Reminder with Cute Plants : 27421.0
# NFL : 27317.0
# Cops N Robbers (FPS) - Block Survival Multiplayer : 27122.0
# Animal Jam - Play Wild! : 26990.0
# Google Translate : 26786.0
# Flashlight for iPhone , iPod and iPad : 26697.0
# Driving School 2016 : 26685.0
# Gilt : 26353.0
# My Mixtapez Music : 26286.0
# HBO GO : 26278.0
# Bad Piggies : 26259.0
# Sing Karaoke Songs Unlimited with StarMaker : 26227.0
# FreePrints – Photos Delivered : 26060.0
# DoorDash - Food Delivery : 25947.0
# SMILE Inc. : 25859.0
# War Dragons : 25834.0
# Tap Sports Baseball 2016 : 25834.0
# Looney Tunes Dash! : 25806.0
# N.O.V.A. 3: Freedom Edition - Near Orbit Vanguard Alliance game : 25716.0
# Triller - Music Video & Film Maker : 25683.0
# Ringtones for iPhone & Ringtone Maker : 25403.0
# Musi - Unlimited Music For YouTube : 25193.0
# Royal Revolt 2 – Defend Your Castle : 25152.0
# Disco Zoo : 24999.0
# Mobile Strike : 24935.0
# Angry Birds Blast : 24878.0
# Turbo Dismount® : 24808.0
# Tank War - Geometry Go Shot Color Dot.IO : 24760.0
# Flashlight ◎ : 24744.0
# Google Sheets : 24602.0
# Survivors: the Quest® : 24547.0
# Wizard of OZ: Magic Match : 24507.0
# Microsoft Excel : 24430.0
# NFL Sunday Ticket : 24258.0
# Mercari: Shopping Marketplace to Buy & Sell Stuff : 24244.0
# Paper.io : 24097.0
# Hungry Shark World : 24057.0
# Pigment - Coloring Book for Adults : 23967.0
# Miitomo : 23965.0
# Clash of Kings - CoK : 23910.0
# Assassin's Creed Pirates : 23895.0
# Vainglory : 23779.0
# Square Cash - Send Money for Free : 23775.0
# Words Crush: Hidden Words! : 23735.0
# Angry Birds Friends : 23655.0
# My Cafe: Recipes & Stories - World Restaurant Game : 23556.0
# SimSimi : 23530.0
# Design Home : 23298.0
# Grindr - Gay and same sex guys chat, meet and date : 23201.0
# 100 PICS Quiz - guess the picture trivia games : 23160.0
# Castle Crush: Epic Strategy Game : 23148.0
# RainbowKey - Color keyboard themes, fonts & GIF : 23063.0
# PAC-MAN 256 - Endless Arcade Maze : 23015.0
# Empires & Allies : 22902.0
# Crazy Taxi™ City Rush : 22877.0
# Storm Radar : 22792.0
# Shopular Coupons, Weekly Deals for Target, Walmart : 22729.0
# Angry Birds Star Wars HD : 22674.0
# Dungeon Hunter 5 - Multiplayer RPG on iOS : 22513.0
# Traffic Racer : 22458.0
# Kill Shot Bravo : 22444.0
# iGun Pro HD - The Original Gun Application : 22324.0
# Where's My Water? 2 : 22302.0
# Airbnb : 22302.0
# Solitaire Classic Card Game™ : 22079.0
# Amazing Thief : 21984.0
# Vlogger Go Viral - Clicker Game & Vlog Simulator : 21977.0
# Inside Out Thought Bubbles : 21881.0
# Capital One for iPad : 21858.0
# MLB.com At Bat : 21830.0
# Restaurant DASH with Gordon Ramsay : 21804.0
# Juice Jam : 21733.0
# Jelly Splash : 21601.0
# Inbox by Gmail : 21561.0
# Colorfly : Coloring Book for Adults - Free Games : 21472.0
# Robot Unicorn Attack 2 : 21432.0
# Gods of Olympus : 21414.0
# RollerCoaster Tycoon® 4 Mobile™ : 21407.0
# Venmo : 21090.0
# Disney Channel – Watch Full Episodes, Movies & TV : 21082.0
# MONOPOLY Bingo! : 21025.0
# The Walking Dead: No Man's Land : 21016.0
# BuzzTube - Video Player for YouTube : 21012.0
# Talking Tom & Ben News for iPad : 20988.0
# Dungeon Boss : 20980.0
# The Championships, Wimbledon 2016 - Tennis Grand Slam : 20953.0
# Tubex - Videos and Music for YouTube : 20943.0
# Roll the Ball™ - slide puzzle : 20911.0
# King of Thieves : 20911.0
# MARVEL Future Fight : 20906.0
# Spinny Circle : 20812.0
# VS. Racing 2 : 20805.0
# Wishbone - Compare Anything : 20649.0
# Minecraft: Story Mode : 20621.0
# happn — Dating app — Find and meet your crush : 20546.0
# Paradise Bay : 20383.0
# Memrise: learn languages : 20383.0
# Peak - Brain Training : 20322.0
# Sugar Smash: Book of Life : 20254.0
# DraftKings - Daily Fantasy Golf, Baseball, & More : 20251.0
# Dubsmash : 20243.0
# Century City : 20147.0
# Adobe Acrobat Reader: View, Create, & Convert PDFs : 20069.0
# Talking Ginger for iPad : 20065.0
# Hot Shot Slots Games – Vegas Casino Slot Machines : 20064.0
# Canvas by Instructure : 19981.0
# T-Mobile : 19977.0
# USAA Mobile : 19946.0
# Drive Ahead! : 19776.0
# Perfect365 - Custom makeup designs and beauty tips : 19540.0
# Heart of Vegas Slots – Casino Slot Machine Games : 19355.0
# EA SPORTS™ UFC® : 19354.0
# LEGO® Star Wars™:  The Complete Saga : 19340.0
# Rodeo Stampede - Sky Zoo Safari : 19199.0
# Racing in Car : 19067.0
# Bad Piggies HD : 19018.0
# Bingo Pop : 18971.0
# The Impossible Quiz! : 18884.0
# imo video calls and chat : 18841.0
# 100! Block Puzzle - Color jigsaw 10x10 board game : 18821.0
# ABCmouse.com - Early Learning Academy : 18749.0
# Dawn of Titans : 18735.0
# Talking Tom Gold Run: Fun & Endless Running Game : 18733.0
# The Washington Post Classic : 18572.0
# RetailMeNot Shopping Deals, Coupons, Savings : 18544.0
# Freeform – watch live TV & stream full episodes : 18492.0
# After School - Funny Anonymous School News : 18482.0
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418.0
# Letter Soup - Word Game : 18358.0
# Ghost Lens+Scary Photo Video Edit&Collage Maker : 18316.0
# Paper by FiftyThree - Sketch, Diagram, Take Notes : 18219.0
# AutoRap by Smule : 18202.0
# Animation Throwdown: The Quest for Cards : 18141.0
# Charades!™ : 18072.0
# Head Basketball : 18037.0
# Poshmark: Buy & Sell Fashion : 18035.0
# Kitchen Scramble: Cooking Game : 17925.0
# Whole Foods Market : 17906.0
# Merged! : 17867.0
# Zombie Castaways : 17865.0
# UberEATS: Uber for Food Delivery : 17865.0
# Quick Reposter - Repost, Regram and Reshare Photos : 17694.0
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588.0
# TaxCaster – Free tax refund calculator : 17516.0
# ipsy - Makeup, subscription and beauty tips : 17489.0
# Bruh-Button : 17487.0
# Willy Wonka Slots: Vegas Casino Slot Machines : 17436.0
# MARVEL Avengers Academy : 17376.0
# X-War: Clash of Zombies : 17254.0
# Disney Magic Kingdoms : 17213.0
# Flip Diving : 17012.0
# Bleacher Report: Sports news, scores, & highlights : 16979.0
# Swamp Attack : 16968.0
# Shooty Skies - Endless Arcade Flyer : 16948.0
# Wallpapers for Me - Themes & Background Images : 16925.0
# Warhammer 40,000: Freeblade : 16879.0
# Roku : 16867.0
# The Silent Age : 16852.0
# Merriam-Webster Dictionary : 16849.0
# Sworkit - Custom Workouts for Exercise & Fitness : 16819.0
# Zombie Catchers : 16805.0
# Weibo HD : 16772.0
# Camera360 - Selfie Filter Camera, Photo Editor : 16729.0
# Univision Deportes: Liga MX, MLS, Fútbol En Vivo : 16683.0
# Quizlet: Study Flashcards, Languages & Vocabulary : 16683.0
# The Line Zen : 16674.0
# MyScript Calculator - Handwriting calculator : 16555.0
# Photomath - Camera Calculator : 16523.0
# DC Legends : 16460.0
# FarmVille: Tropic Escape - Harvest in Paradise : 16457.0
# NASCAR MOBILE : 16385.0
# Sonic CD : 16358.0
# Plants vs. Zombies™ Heroes : 16305.0
# Farm Heroes Super Saga: Match, Collect and Grow! : 16259.0
# Over— Edit Photos, Add Text & Captions to Pictures : 16221.0
# InstaMag - Free Pic and Photo Collage Maker : 16221.0
# The Walking Dead: Road to Survival - Strategy Game : 16116.0
# 5miles: Buy and Sell Used Stuff Locally : 16105.0
# Cartoon Network App – Teen Titans Go! And more! : 15984.0
# Disney Movies Anywhere: Watch Your Disney Movies! : 15900.0
# Tap Tap Fish - Abyssrium : 15876.0
# iTunes U : 15801.0
# ColorArt: Coloring Book For Adults : 15797.0
# Photo Transfer App - Easy backup of photos+videos : 15654.0
# Forge of Empires : 15617.0
# InstaSize: Photo Editor, Picture Effects & Collage : 15605.0
# Sephora Makeup & Beauty App – Insider Tips & Style : 15593.0
# NHL : 15554.0
# Ninja Kid Run VR: Runner & Racing Games For Free : 15399.0
# FIFA Mobile Soccer : 15365.0
# Cupcake Mania™ : 15336.0
# Hovercraft: Takedown - Custom Combat Cars : 15290.0
# Repost for Instagram : 15185.0
# Prisma: Photo Editor, Art Filters Pic Effects : 15060.0
# Spinrilla - Mixtapes For Free : 15053.0
# Flappy Golf : 14995.0
# Calculator HD Free : 14986.0
# Filterra – Photo Editor, Effects for Pictures : 14744.0
# Live.me – Live Video Chat & Make Friends Nearby : 14724.0
# Cartwheel by Target : 14682.0
# Arrow : 14673.0
# Zombie Highway 2 : 14593.0
# Traffic Rider : 14592.0
# Six! : 14505.0
# Fruit Nibblers : 14505.0
# Deer Hunter 2017 : 14461.0
# Nextdoor : 14402.0
# Napster - Top Music & Radio : 14268.0
# Bottle Flip 2k16 : 14263.0
# XFINITY Stream : 14198.0
# YouCam Makeup: Magic Makeup Selfie Cam : 14188.0
# Hovercraft - Build Fly Retry : 14123.0
# Top Eleven 2017 - Be a Soccer Manager : 14104.0
# Followers Analytics for Instagram - InstaReport : 13914.0
# FOX Sports GO : 13898.0
# Snakeio : 13870.0
# WWE SuperCard : 13842.0
# 94% : 13805.0
# VPN Proxy Master - Unlimited WiFi security VPN : 13674.0
# Transformers: Earth Wars : 13664.0
# Slots - Huuuge Casino: Slot Machines : 13637.0
# edjing Mix:DJ turntable to remix and scratch music : 13580.0
# NCAA March Madness Live - Men's College Basketball : 13572.0
# Blackboard Mobile Learn™ : 13567.0
# Pokémon TCG Online : 13559.0
# Star Chart : 13482.0
# Free Music - MP3 Streamer & Playlist Manager Pro : 13443.0
# Clue Period Tracker: Period & Ovulation Tracker : 13436.0
# my KONAMI Slots - Vegas Casino Slot Machine Games : 13345.0
# CPlus for Craigslist app - mobile classifieds : 13345.0
# KleptoCats : 13300.0
# Regal Cinemas : 13257.0
# Churchill Solitaire - World War Card Game : 13241.0
# Nick : 13237.0
# Farm Story 2™ : 13142.0
# Phoenix HD : 13106.0
# Block Сity Wars: game and skin export to minecraft : 13097.0
# Free Piano app by Yokee : 13016.0
# MSQRD — Live Filters & Face Swap for Video Selfies : 12982.0
# Artisto – Video and Photo Editor with Art Filters : 12963.0
# MMX Racing : 12854.0
# Headspace : 12819.0
# Geocaching® : 12811.0
# Microsoft OneDrive – File & photo cloud storage : 12797.0
# InShot Video Editor Music, No Crop, Cut : 12779.0
# Ever - Capture Your Memories : 12755.0
# QR Reader for iPhone : 12683.0
# BIG WIN Basketball : 12669.0
# SHEIN Shopping - Women's Clothing & Fashion : 12663.0
# Ebates: Cash Back, Coupons & Rebate Shopping App : 12617.0
# Layout from Instagram : 12616.0
# Wayfair - Shop Furniture, Home Decor, Daily Sales : 12578.0
# The Trail : 12573.0
# cute icon&wallpaper dressup - CocoPPa : 12508.0
# Steppy Pants : 12506.0
# CVS : 12402.0
# Football Clicker : 12326.0
# SNKRS : 12298.0
# Fair Food Maker Game - Make Yummy Carnival Treats : 12251.0
# ElfYourself by Office Depot, Inc. : 12177.0
# Rick and Morty: Pocket Mortys : 12124.0
# CLUE Bingo : 12123.0
# Night Sky : 12122.0
# YouNow: Live Stream Video Chat : 12079.0
# Hop : 12079.0
# Solitaire Ⓞ : 12077.0
# WIRED Magazine : 12074.0
# Speak & Translate － Voice and Text Translator : 12062.0
# Extreme Fishing 2 Free : 12002.0
# AgingBooth : 11999.0
# Face Swap App- Funny Face Changer Photo Effects : 11977.0
# FollowMeter for Instagram - Followers Tracking : 11976.0
# Moments - private albums with friends and family : 11955.0
# Haunted Halloween Escape : 11945.0
# Pakka Pets Village - Build a Cute Virtual Pet Town : 11933.0
# Dots: A Game About Connecting : 11900.0
# Wheel of Fortune: Game Show Word Puzzles : 11876.0
# Fooducate - Lose Weight, Eat Healthy,Get Motivated : 11875.0
# Hair Color Changer - Styles Salon & Recolor Booth : 11828.0
# Skyline Skaters : 11785.0
# Tap Tap Dash : 11748.0
# Scanner App - PDF Document Scan : 11696.0
# CBS News - Watch Free Live Breaking News : 11691.0
# Puffin Web Browser : 11677.0
# Talking Pierre the Parrot for iPad : 11665.0
# Mobile Legends: Bang bang : 11602.0
# Peggle Blast : 11528.0
# Tayasui Sketches : 11505.0
# LINE : 11437.0
# Amex Mobile : 11421.0
# Lep's World 3 : 11341.0
# War Machines: 3D Multiplayer Tank Shooting Game : 11325.0
# Dumb Ways to Die 2: The Games : 11295.0
# Flick Kick Football Legends : 11250.0
# VSCO : 11174.0
# Bee Brilliant : 11151.0
# eHarmony™ Dating App - Meet Singles : 11124.0
# MMX Hill Dash — Off-Road Racing : 11123.0
# Rayman Adventures : 11100.0
# PrankDial - #1 Prank Call App : 11091.0
# Snapimals: Discover & Snap Amazing & Cute Animals! : 11060.0
# Drawing Desk - Draw, Paint, Doodle & Sketch board : 11040.0
# Tap Tycoon - Country vs Country : 11034.0
# Retrica - Selfie Camera with Filter, Sticker & GIF : 11021.0
# Macy's : 11013.0
# Microsoft PowerPoint : 10939.0
# Dictator: Outbreak : 10871.0
# Sunken Secrets : 10849.0
# Email - Fast & Secure mail for Gmail iCloud Yahoo : 10778.0
# Teenage Mutant Ninja Turtles: Legends : 10771.0
# Rival Fire : 10701.0
# Dots & Co: A New Puzzle Adventure : 10693.0
# AliExpress Shopping App : 10647.0
# VivaVideo - Best Video Editor & Photo Movie Maker : 10618.0
# War Tortoise : 10555.0
# RPG AVABEL ONLINE : 10514.0
# Prime Photos from Amazon : 10511.0
# PGA Championship 2016 – Baltusrol Golf Club : 10472.0
# Monster Super League : 10368.0
# Hide N Seek : Mini Multiplayer Game : 10358.0
# Runtastic Running, Jogging and Walking Tracker : 10298.0
# Expedia Hotels, Flights & Vacation Package Deals : 10278.0
# Cat Kitty Kitten Coloring Pages - Free Girl Games : 10278.0
# Mahjong Classic Board Game : 10275.0
# Lords Mobile : 10263.0
# Stupid Zombies 3 : 10159.0
# Weed Firm: RePlanted : 10122.0
# Google Play Music : 10118.0
# Bumble – Find a Date, Meet Friends & Network : 10109.0
# Fresh Tracks Snowboarding : 10107.0
# Certified Mixtapes - Hip Hop Albums & Mixtapes : 9975.0
# High 5 Casino - Real Vegas Slots! : 9930.0
# Google Slides : 9920.0
# 365Scores : 9879.0
# Mr. Crab : 9875.0
# HP All-in-One Printer Remote : 9819.0
# Remind: Fast, Efficient School Messaging : 9796.0
# Genies & Gems : 9768.0
# ASOS : 9725.0
# Restaurant Story 2 : 9699.0
# TurboTax Tax Return App - File 2016 income taxes : 9635.0
# Postmates - Food Delivery, Faster : 9519.0
# SongPop 2 - Guess The Song : 9517.0
# FXNOW - Full Episodes, Movies, and Stream Live TV : 9496.0
# Mini Golf Stars! Retro Golf Game : 9411.0
# diep.io : 9397.0
# Afterpulse : 9321.0
# Google Home : 9303.0
# Bullet Force : 9289.0
# Batman: Arkham Underworld : 9287.0
# Evolution Calculator - CP & XP - for Pokemon GO! : 9269.0
# Tank.IO War - Free Tank games of snake : 9259.0
# Discord - Chat for Gamers : 9152.0
# WebMD for iPad : 9142.0
# Tap Titans 2 : 9122.0
# Canva - Graphic Design & Photo Editing : 9114.0
# Sonic & All-Stars Racing Transformed : 9109.0
# QQ : 9109.0
# Photo Editor- : 9095.0
# Dunkin' Donuts - Get Offers, Coupons & Rewards : 9068.0
# Snake Slither Run - Hungry Worm Eat Color Dot : 9034.0
# StubHub - Tickets to Sports, Concerts and Theatre : 9011.0
# ZEDGE™ Ringtones : 9010.0
# Jet: Online Shopping Deals & Bulk Wholesale Prices : 9006.0
# STARZ : 8971.0
# IKEA Catalog : 8939.0
# Dear Diary - Interactive Story : 8922.0
# Archery King : 8905.0
# Mimitos Virtual cat with minigames : 8899.0
# Gboard — a new keyboard from Google : 8873.0
# Despicable Bear - Top Beat Action Game : 8872.0
# Smashy City : 8742.0
# 8fit - Workouts, meal plans and personal trainer : 8730.0
# Snapseed : 8683.0
# PBS KIDS Video : 8651.0
# SayHi Translate : 8623.0
# Sniper Fury: Fun Mobile Shooter Game : 8596.0
# Crazy Taxi : 8573.0
# Romwe shopping- Fashion Clothing for women : 8558.0
# Fit The Fat 2 : 8557.0
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535.0
# You Doodle - draw on photos & pictures, add text : 8520.0
# Stop - Fun Categories Word Game : 8516.0
# PIP Camera-Selfie Cam&Pic Collage&Photo Editor : 8454.0
# My Emma :) : 8412.0
# Spin It Rich! Casino Slots: Free Slot Machines : 8402.0
# Futurama: Game of Drones : 8394.0
# One More Line : 8392.0
# Garmin Connect™ Mobile : 8341.0
# ADP Mobile Solutions : 8324.0
# Talking Ginger 2 : 8311.0
# Diggy's Adventure : 8271.0
# NFL Fantasy Football - Official NFL Fantasy App : 8234.0
# Pet Buddies HD : 8227.0
# Black Friday 2017 Ads App - BlackFriday.fm : 8221.0
# The Guardian : 8176.0
# Mekorama : 8157.0
# Sam's Club: Wholesale Shopping & Bulk Buy Deals : 8149.0
# Fly Delta : 8094.0
# Disney Junior – Watch Full Episodes, Movies & TV : 8077.0
# Toca Kitchen Monsters : 8062.0
# Tomb of the Mask : 8054.0
# Toca Hair Salon - Christmas Gift : 8049.0
# Kids Doodle - Movie Kids Color & Draw : 8025.0
# FanDuel - Daily Fantasy Baseball, Golf & Sports : 8014.0
# Swing : 8013.0
# Vikings: War of Clans : 7969.0
# Fantasy Forest Story: Land Before Dragons : 7935.0
# Sideline - 2nd Phone Number : 7907.0
# Run!!! : 7891.0
# Pokémon Duel : 7868.0
# Clash of Lords 2: New Age : 7795.0
# Soccer Star 2016 World Legend : 7765.0
# Record by Under Armour, connects with UA HealthBox : 7754.0
# Steve - The Jumping Dinosaur Widget Arcade Game : 7751.0
# My Singing Monsters: Dawn of Fire : 7749.0
# Burrito Bison: Launcha Libre : 7740.0
# Coloring Book for Me - Coloring pages for adults : 7692.0
# DragonSoul RPG : 7681.0
# Tactile Wars : 7674.0
# Google Calendar – Make the most of every day : 7656.0
# Quick Hit Slots – Casino Slot Machines Games : 7646.0
# Galaxy on Fire 3 - Manticore : 7609.0
# Telegram Messenger : 7573.0
# Bank of America - Mobile Banking for iPad : 7569.0
# WWE : 7553.0
# GolfNow – Book Tee Times, Golf GPS, Scorecard : 7535.0
# Dan The Man (Retro Action Platformer) : 7527.0
# POP! Slots – Las Vegas Casino Slot Machine Games : 7518.0
# Crafty Candy - Match 3 Puzzle Game : 7511.0
# BeautyPlus - Selfie Camera for a Beautiful Image : 7503.0
# Fitstar Personal Trainer : 7496.0
# Clicker Heroes : 7495.0
# Bejeweled Stars : 7486.0
# HBO NOW: Stream original series, hit movies & more : 7477.0
# My Cycles Period and Ovulation Tracker : 7469.0
# Sky Force Reloaded : 7429.0
# Monogram - Wallpaper & Backgrounds Maker HD DIY with Glitter Themes : 7427.0
# Super Cat Tales : 7423.0
# TIDAL : 7398.0
# RoverCraft Space Racing : 7375.0
# BBTAN by 111% : 7367.0
# Free QR Code Reader & Barcode Scanner for iPhone : 7343.0
# Weibo : 7265.0
# PlayStation®App : 7256.0
# Edmodo : 7197.0
# Builder Buddies: 3D City Building Simulator : 7197.0
# Slots: DoubleUp Free Slot Games - Slot Machines : 7177.0
# Kohl's App: Scan, Shop, Pay and Save! : 7174.0
# Word Search Colorful : 7131.0
# YouTube Music : 7109.0
# Smash Monsters - City Rampage : 7084.0
# Hungry Babies Mania : 7075.0
# Olympus Rising : 7072.0
# StickyBalls Deluxe - Addicting Fall Down Game : 7002.0
# Christmas Food Fever Cooking Maker Kids Games : 6975.0
# Solitaire Deluxe® Social - Classic, Spider, more : 6970.0
# The Impossible Letter Game : 6956.0
# Hopper - Predict, Watch & Book Flights : 6944.0
# Christmas Dentist Doctor Kid Games (Girls & Boys) : 6917.0
# Best Fiends Forever : 6872.0
# No Brakes : 6865.0
# Watch TNT : 6856.0
# Nonstop Knight : 6841.0
# Fist of Fury : 6813.0
# Seven - 7 Minute Workout Training Challenge : 6808.0
# Mystic Messenger : 6754.0
# Baby Story - Pregnancy Pics Baby Milestones Photo : 6700.0
# Tinker Island: Survival Adventure : 6686.0
# Prodigy Math Game : 6683.0
# Flipp - Weekly Ads, Shopping List, and Coupons : 6677.0
# Epic! - Unlimited Books for Kids : 6676.0
# Nerve — Truth or Dare Dirty Houseparty Party Games : 6658.0
# Hidden Objects: Mystery Society: Solve Crime Cases : 6624.0
# Touchdown Hero : 6570.0
# Mahjong Treasure Quest : 6557.0
# Suicide Squad: Special Ops : 6551.0
# Capture - Control Your GoPro Camera - Share Video : 6542.0
# Zen Pinball : 6534.0
# Bud Farm: Grass Roots : 6523.0
# Pixel Color Ball Fell From The Sky : 6493.0
# Verizon Cloud : 6482.0
# Would You Rather? : 6479.0
# Meitu : 6478.0
# Pineapple Pen : 6430.0
# NARUTO SHIPPUDEN: Ultimate Ninja Blazing : 6426.0
# AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes : 6408.0
# RUNNING for weight loss: workout & meal plans : 6407.0
# DragonVale World : 6379.0
# Order & Chaos 2: 3D MMO RPG Online Game : 6325.0
# Endless Sky : 6313.0
# Taps to Riches : 6286.0
# Good Knight Story : 6282.0
# Real Boxing 2 ROCKY : 6263.0
# Twin Moons Society™: Hidden Mystery : 6219.0
# Cheats For Pokemon Go - Gameplay, PokeCoins Guide, Catch Videos : 6205.0
# Faily Brakes : 6183.0
# LEGO® Juniors Create & Cruise : 6152.0
# Mars: Mars : 6116.0
# SeatGeek – Tickets to Sports, Concerts & Broadway : 6088.0
# Live Wallpapers by Themify: Dynamic Animated Theme : 6083.0
# QuakeFeed Earthquake Map, Alerts, and News : 6081.0
# Dragon Land : 6079.0
# ChineseSkill -Learn Mandarin Chinese Language Free : 6077.0
# Periscope - Live Video Streaming Around the World : 6062.0
# Battle Camp HD - Collect & Evolve Your Monsters : 6055.0
# Thumb Drift - Furious One Touch Car Racing : 6051.0
# Fish Mania™ : 6038.0
# Cops N Robbers (Jail Break) - Survival Mini Game : 6013.0
# Disney Junior Appisodes : 6009.0
# MTV : 5987.0
# GIF Keyboard : 5979.0
# Google Classroom : 5942.0
# Free VPN HexaTech - Unlimited VPN Proxy for iPhone : 5934.0
# Ball King : 5834.0
# Ketchapp Basketball : 5833.0
# Pokémon Shuffle Mobile : 5805.0
# Lifesum – Inspiring healthy lifestyle app : 5795.0
# TED : 5782.0
# Snake.io - Worm.io - Agar Slither Snake Battle : 5768.0
# Visage makeup editor plus photo teeth whitener : 5767.0
# Bakery Story 2 : 5753.0
# United Airlines : 5748.0
# Soda Dungeon : 5717.0
# Disney XD – Watch Full Episodes, Movies & Live TV : 5703.0
# Sonic Dash 2: Sonic Boom : 5697.0
# Sling TV: A La Carte TV. Watch Live Shows & Sports : 5693.0
# Tile - Find & track your lost phone, wallet, keys : 5684.0
# Youku HD : 5683.0
# Video & TV Cast for Chromecast: Best Browser to cast and stream webvideos and local videos on TV & Displays : 5676.0
# Chick-fil-A : 5665.0
# Green the Planet : 5660.0
# Nom Cat - Endless feeding frenzy arcade game : 5655.0
# Does not Commute : 5645.0
# Pixel Starships™ : 8Bit MMORPG : 5565.0
# Gods Of Rome : 5526.0
# Everpix HD Wallpapers - Cool Backgrounds & Themes : 5521.0
# E! Now : 5506.0
# PKTBALL - Endless Arcade Smash Sport : 5492.0
# Brain Dots - Draw and solve! Brain Training Game : 5469.0
# Nike+ : 5464.0
# Khan Academy: you can learn anything : 5459.0
# Sam’s Club Scan & Go : 5448.0
# Force Saber of Light : 5424.0
# DRAGON BALL Z DOKKAN BATTLE : 5362.0
# Ticketmaster - Tickets for Concerts, Sports, Shows : 5356.0
# Face Swap Booth – photo faceswap & face changer : 5300.0
# Adobe Photoshop Mix - Cut out, combine, create : 5253.0
# Clockmaker – Mystery Match3 Puzzle : 5246.0
# School of Chaos Online MMORPG : 5237.0
# AOL: News, Email, Weather & Video : 5233.0
# Baby Care & Dress Up - Love & Have Fun with Babies : 5230.0
# Skinseed - Skin Creator for Minecraft Skins : 5222.0
# RISK: Global Domination : 5217.0
# Nicki Minaj: The Empire : 5196.0
# Kritika: The White Knights : 5185.0
# Grumpy Cat's Worst Game Ever : 5170.0
# Online Head Ball : 5160.0
# Hand of God - Top Clicker & Tap Games : 5141.0
# Make More! : 5134.0
# Real Fishing 3D Free : 5131.0
# Sounds app - Music And Friends : 5126.0
# Geometry Dash World : 5114.0
# Tap Smiths : 5112.0
# Collageable - Photo Collage Maker, Pic Grid Free : 5112.0
# Ghostbusters™: Slime City : 5111.0
# My Bowling 3D : 5090.0
# Chat for Whatsapp - iPad Version : 5060.0
# QQ HD : 5058.0
# Princess Salon™ - Girls Makeup, Dressup and Makeover Games : 5030.0
# Close5 - Buy & Sell Stuff Locally : 5010.0
# SongFlip - Free Music Streamer : 5004.0
# PinOut! : 5003.0
# Waterlogged - Daily Hydration Tracker : 5000.0
# Bold Moves : 4980.0
# Alarm Clock for Me - Best Wake Up Music & Clock : 4959.0
# Magic Tiles : Music Maker - Don't Touch the White : 4944.0
# The Last Vikings : 4919.0
# Doomsday Clicker : 4910.0
# Bazaart Photo Editor Pro and Picture Collage Maker : 4909.0
# Pancake – The Game : 4903.0
# Got It - Homework Help Math, Chem, Physics Solver : 4903.0
# Solitaire Free: card games for adults : 4891.0
# Checkout 51: Grocery Coupons & Cash Back Savings : 4878.0
# Retale - Coupons, Weekly Ads & Stores Nearby : 4861.0
# J&J Official 7 Minute Workout : 4861.0
# InstaBeauty -Camera&Photo Editor&Pic Collage Maker : 4818.0
# BLEACH Brave Souls : 4815.0
# Monster Craft GO - Find and Catch pixelmon CarToon : 4808.0
# Simple Radio - Live AM & FM Radio Stations : 4787.0
# Quick Scan - QR Code Reader : 4783.0
# Productive habits & daily goals tracker : 4736.0
# Star Trek Timelines : 4721.0
# Fight List : 4702.0
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693.0
# Deezer - Listen to your Favorite Music & Playlists : 4677.0
# Fitbod Workout Log: Strength Lifting Bodybuilding : 4668.0
# PNP 2016 Portable North Pole—Create Santa Videos : 4650.0
# SmartNews - Trending News & Stories : 4645.0
# Voice Recorder (FREE) : 4640.0
# Sling Kong : 4638.0
# Crazy Cake Swap : 4638.0
# BattleHand : 4623.0
# Legacy of Discord - Furious Wings : 4618.0
# WordBrain 2 : 4577.0
# Blocky Football : 4549.0
# PowerSchool Mobile : 4547.0
# Trump Dump ⁢ : 4544.0
# Sandstorm: Pirate Wars : 4518.0
# Tankio - Battle Arena : 4513.0
# Shuffle Cats : 4499.0
# Narcos: Cartel Wars : 4490.0
# Craft your games! - Createrria 2 : 4475.0
# Twisty Arrow - Shoot the Circle Wheel : 4440.0
# Lock Screens - Free Wallpapers & Background Themes : 4429.0
# Weed Firm 2: Back To College : 4387.0
# Beach Buggy Racing : 4386.0
# BB-8™ App Enabled Droid Powered by Sphero : 4385.0
# Rival Stars Basketball : 4383.0
# Warrior Balls : 4375.0
# Flick Quarterback 17 : 4371.0
# Jam League : 4361.0
# MiP App : 4350.0
# Descendants : 4333.0
# Cut the Rope: Time Travel Free : 4327.0
# Adobe Spark Video, Animated Videos in minutes : 4302.0
# YouCam Perfect - Photo & Selfie Editor : 4293.0
# Runtastic Six Pack Abs Workout & Core Trainer : 4283.0
# Card Wars Kingdom - Adventure Time : 4283.0
# PHHHOTO - Look Alive : 4280.0
# Diamond Quest! : 4278.0
# Invasion: Modern Empire : 4276.0
# YO-KAI WATCH Wibble Wobble : 4275.0
# MuseCam - Edit Photos & Manual Camera : 4267.0
# Peanuts: Snoopy's Town Tale : 4260.0
# Followers Analysis Tool For Instagram App Free : 4253.0
# Total - Free browser with file manager and cloud storage support : 4231.0
# Risky Road : 4226.0
# NCIS: Hidden Crimes : 4222.0
# SkyView® Free - Explore the Universe : 4188.0
# Kmart – Download Now, Shop Online & Pick Up Today! : 4186.0
# Slash Mobs : 4179.0
# Naughty Kitties : 4162.0
# Emoji Keyboard for Me - Free Emoji Keyboard Themes : 4162.0
# live.ly - live video streaming : 4145.0
# VR Tube - Virtual Reality 360 Video Player : 4142.0
# Land Sliders : 4142.0
# Fyuse - 3D Photos : 4126.0
# Fun Run Arena - Online Multiplayer Running Game : 4116.0
# Atom – Movie Tickets and Showtimes : 4105.0
# Frozen Frenzy Mania: Challenging Match 3 Games : 4104.0
# Oz: Broken Kingdom™ : 4074.0
# Hopscotch : 4057.0
# Vudu - Movies & TV : 4052.0
# Watch TBS : 4050.0
# McDonald's : 4050.0
# Guess The Song - New music quiz! : 4050.0
# Big Win Football 2016 : 4035.0
# Calculator for iPad Free. : 4021.0
# Ringtones for iPhone with Ringtone Maker : 4013.0
# Loop Drive 2 : 4009.0
# Houseparty - Group Video Chat : 3991.0
# MakeupPlus - Natural, Professional Makeup Looks : 3987.0
# Dashy Crashy : 3979.0
# LINE Camera - Photo editor, Animated Stamp, Filter : 3978.0
# Fireboy and Watergirl: Online in the Forest Temple - Multiplayer Running and Adventure Game : 3965.0
# Kids Shave Salon Spa Games (Boys & Girls) : 3963.0
# Asphalt Xtreme: Offroad Rally Racing : 3960.0
# Slots: Hot Vegas Slot Machines - Free Slot Games : 3938.0
# Scanbot - Scanner App & Fax : 3936.0
# STAR WARS™: FORCE COLLECTION : 3936.0
# World Craft HD : 3933.0
# Printicular Print Photos - 1 Hour Pickup : 3909.0
# Lumyer - augmented reality camera effects : 3896.0
# Watch OWN : 3895.0
# Scrubby Dubby Saga : 3874.0
# War Commander: Rogue Assault : 3858.0
# A Call From Santa! Voicemail & Text Messages : 3823.0
# Ryder Cup 2016 – Hazeltine National Golf Club : 3818.0
# Athlete Shave Salon Games : 3815.0
# Yellow - Make new friends : 3809.0
# Slots - Lucky Win Casino Games & Slot Machines : 3807.0
# Sweat: Kayla Itsines' Bikini Body Fitness Workouts : 3788.0
# Pou : 3783.0
# Smart Alarm Clock : sleep cycle & snoring recorder : 3779.0
# Word Trek  - WordTrek Brain game & Word puzzles : 3774.0
# Troll Face Quest Video Memes : 3770.0
# Leap Day : 3763.0
# The Battle of Polytopia : 3757.0
# JibJab : 3755.0
# Ketchapp Summer Sports : 3731.0
# KODAK Kiosk Connect App : 3711.0
# Cool Wallpapers for Pokemon : 3694.0
# MSNBC : 3692.0
# Cookie Cats - a singing puzzle adventure : 3687.0
# Bose SoundTouch : 3687.0
# My Challenge Tracker : 3682.0
# Pro Editor - Video Maker for FaceBook & Youtube : 3668.0
# MOBIUS FINAL FANTASY : 3640.0
# UNKILLED: MULTIPLAYER ZOMBIE SURVIVAL SHOOTER GAME : 3634.0
# Game of Dice : 3629.0
# Farming Simulator 14 : 3615.0
# COOKING MAMA Let's Cook！ : 3594.0
# CoPilot GPS – Car Navigation & Offline Maps : 3582.0
# IXL - Math and English : 3546.0
# It Girl Story - Styling, Fashion & Celebrity Life : 3537.0
# Lomotif Music Video Editor - Add Music & Effects! : 3507.0
# Down The Mountain : 3491.0
# Bubble Island 2 - Pop Bubble Shooter : 3480.0
# Wheel of Fortune Slots Casino with Vanna White : 3413.0
# Trial Xtreme 4 : 3403.0
# Rolling Snake.io - Worm IO Multiplayer Online Slither War Game - Free Agar Skins Version : 3392.0
# Bottle Flip! : 3384.0
# Wordalot – Picture Crossword : 3383.0
# TETRIS® FREE : 3383.0
# Horizon Chase - World Tour : 3375.0
# The Maze Runner ™ : 3370.0
# Lara Croft: Relic Run : 3366.0
# go90 – Stream TV & Live Sports : 3355.0
# Home - Design & Decor Shopping : 3354.0
# Stormfall: Rise of Balur : 3340.0
# Make7! Hexa Puzzle : 3336.0
# The Voice Official App on NBC : 3327.0
# King of Avalon: Dragon Warfare : 3326.0
# Last Empire – War Z: Zombie Strategy Game : 3323.0
# Uber Driver : 3289.0
# Prize Wheel ™ : 3287.0
# McPlay™ : 3278.0
# Trivia Crack Kingdoms : 3250.0
# Sky Whale - a Game Shakers App : 3248.0
# Zig Zag Boom : 3242.0
# SOMA Messenger : 3232.0
# The Sandbox Evolution - Craft a 2D Pixel Universe : 3220.0
# Tank.io war - Free Classic Tank games : 3219.0
# PES CLUB MANAGER : 3216.0
# Adobe Illustrator Draw : 3215.0
# Word Flow Keyboard - GIF, swipe, custom theme : 3213.0
# T-Mobile Tuesdays : 3213.0
# Smashy Road: Arena : 3207.0
# LEGO® Star Wars™: The Force Awakens : 3207.0
# Onefootball - Soccer Scores & Live News : 3194.0
# Plants vs. Zombies FREE HD : 3185.0
# Nono Islands : 3180.0
# Honest App: Shop baby & diaper products : 3173.0
# White Tiles 4: Piano Master (All mini games in 1) : 3168.0
# Buffalo Slots - Royal Casino Fun Slot Machines! : 3153.0
# Twisty Wheel : 3148.0
# Digimon Heroes! : 3144.0
# Hot Wheels: Race Off : 3141.0
# Sunday Ticket : 3134.0
# Basketball Clicker : 3130.0
# MLB 9 Innings 17 : 3120.0
# GOAT: Buy & Sell Sneakers : 3116.0
# Charity Miles: Walking & Running Distance Tracker : 3115.0
# Kylie Jenner Official App : 3111.0
# AMC : 3105.0
# Concepts - Sketch, Design, Illustrate : 3101.0
# Total War Battles: KINGDOM : 3092.0
# Build Away! - Idle City Game : 3065.0
# Monkey : 3060.0
# Shopkins World! : 3047.0
# Magic Rush: Heroes : 3046.0
# Taxi Sim 2016 : 3026.0
# AT&T Mobile Transfer - Free : 3024.0
# Football Heroes PRO 2016 : 3018.0
# Amazon Alexa : 3018.0
# The Paranormal Society™: Hidden Adventure : 3000.0
# 50 50 - The Addictive Slicing Game : 2998.0
# KINGDOM HEARTS Union χ[Cross] : 2984.0
# Water Bottle Flip Challenge 2 : 2964.0
# Slam Dunk Basketball 2 - Play & Do Good : 2963.0
# Spellspire : 2939.0
# PolitiCats: Awesome Clicker Game : 2938.0
# Simply Piano by JoyTunes - Learn & play piano : 2925.0
# Battle Copters : 2922.0
# Cookie Clickers 2 : 2912.0
# Javelin Masters 2 : 2909.0
# Sea Hero Quest : 2908.0
# Love and Hip Hop The Game : 2908.0
# Ab & Core Sworkit - Free Workout Trainer : 2901.0
# NFL HUDDLE: Football Card Trader : 2896.0
# Alpha Omega : 2892.0
# Jupiter Jump : 2890.0
# Kids A-Z : 2887.0
# Fernanfloo : 2886.0
# Shopkins: Chef Club : 2881.0
# Solitaire ∞ : 2865.0
# Lollipop: Sweet Taste Match3 : 2861.0
# Talking Tom Jetski : 2853.0
# Epson iPrint : 2838.0
# Skiing Yeti Mountain : 2830.0
# 1+2=3 : 2816.0
# DatPiff : 2815.0
# Trello : 2793.0
# Gear.Club - True Racing : 2793.0
# Flow Free: Hexes : 2791.0
# Galaxy Reavers-Space Strategy game(RTS) : 2778.0
# Juju on the Beat : 2772.0
# World of Cubes Survival Craft : 2758.0
# Big Bang Racing : 2758.0
# Pocket Politics : 2748.0
# Amateur Surgeon 4 : 2743.0
# Tennis Champs Returns : 2740.0
# Ingress : 2739.0
# Slots: VIP Deluxe Slots Machines - Free Slot Games : 2732.0
# ZARA : 2731.0
# Mahjong Solitaire Star! Your Favorite Game! : 2731.0
# MANSION MAPS for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 2720.0
# Lookout: Security and Identity Theft Protection : 2661.0
# Talking Tom Bubble Shooter : 2659.0
# Christmas Sweeper 3 : 2645.0
# KICK: Official Football Card Trader : 2641.0
# Super Atomic : 2638.0
# Star Trek ® - Wrath of Gems : 2636.0
# Hudl : 2622.0
# Firefox web browser : 2619.0
# ...
# Diced - A Simple Puzzle Dice Game : 53.0
# Color 6: Blitz : 53.0
# Osmo Numbers : 52.0
# Osmo Monster : 52.0
# lollicam - photo, video, and selfie camera : 51.0
# Hexy! : 51.0
# Dr. Panda Toy Cars Free : 51.0
# Virry Educational. Play, learn with real animals : 50.0
# Virginia Tech Emoji : 50.0
# Toast Girl : 50.0
# Teeter – Endless Arcade Balancer : 50.0
# Target Acquired : 50.0
# FreeFlight Mini : 50.0
# Simeji - Japanese Keyboard with Emoticons : 49.0
# PlayKids Learn - Learning through play : 49.0
# Lock The Block : 49.0
# Jordan Keyboard : 49.0
# Highlights Monster Day : 49.0
# Five Finger Fury : 49.0
# Escape Game: Relief : 49.0
# What Jump - Free Pop Arcade Game : 48.0
# Top Tier : 48.0
# Ball Escape! : 48.0
# Stickman Cubed : 47.0
# Spirit Rush : 47.0
# Dot Empires : 47.0
# Valley of Fear Virtual Reality : 46.0
# VR Ball for Google Cardboard Virtual Reality : 46.0
# Smart Virtual Boyfriend : 46.0
# SFR TV : 46.0
# Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : 46.0
# Princess Face Paint - Girls Makeup, Dressup and Makeover Games : 45.0
# Zaim : 44.0
# Santa Calls You Free : 44.0
# Extreme Heavy Trucker Parking Simulator : 44.0
# Chunky Tanks : 44.0
# Zombies Chasing Me : 43.0
# Water Bottle Flip Challenge : 2k16 : 43.0
# TCS NYC Marathon : 43.0
# Ridiculous Parking Simulator a Real Crazy Multi Car Driving Racing Game : 43.0
# MY EE : 43.0
# Curvulate : 43.0
# Critter Academy : 43.0
# Vendée Globe 2016 : 42.0
# The Walk VR : 42.0
# Pixel Strike-Sniper zombies shooting games : 42.0
# Monster Busters: Link Flash : 42.0
# Hillarymoji : 42.0
# Helper for Pokemon Go : 42.0
# Tapage by My Little App : 41.0
# Santa Kids Hair Salon - Christmas Makeover Games : 41.0
# Hugo Flower Flush : 41.0
# Hovercrash : 41.0
# Geki Yaba Runner : 41.0
# Gate Keepers : 41.0
# Escape Game: Signs : 41.0
# Dashy Box : 41.0
# City Car Driving : 41.0
# WSVN Hurricane Tracker : 40.0
# No Limit Racer : 40.0
# Morning Routine : Daily Habit Tracker : 40.0
# DingTalk : 40.0
# Behind You!! : 40.0
# Warcher Defenders : 39.0
# Spike Run : 39.0
# Hell Run - Scary Road : 39.0
# Fake call from the Easter Bunny : 39.0
# Dashy the Cat : 39.0
# CTFxCmoji : 39.0
# Sky Viper Flight Simulator : 38.0
# Pursuit of Light2 : 38.0
# PBS KIDS ScratchJr : 38.0
# NRJ Radio : 38.0
# Limo Driving School a Valet Driver License Test Parking Simulator : 38.0
# Forest Heroes Story : 38.0
# Face Paint Party - Kids Coloring Fun : 38.0
# Cubicle. : 38.0
# 25 Days of Christmas: Holiday Advent Calendar 2016 : 38.0
# Weather & Radar : 37.0
# TRUMP Yo'Self! Make Your Hair Great Again! : 37.0
# Re:Monster : 37.0
# Race Driving School Car Racing Driver License Test : 37.0
# Emily’s Polar Adventure : 37.0
# Election Center 2016 : 37.0
# Catch Santa Claus in my house for Christmas : 37.0
# Wellbeyond Meditation for Kids : 36.0
# Ocean Clash: A naval game with honor and loyalty : 36.0
# Lobi : 36.0
# Where's My What? Free : 35.0
# Waiit : 35.0
# Our dark lord-Sasuyu 2-TAP RPG : 35.0
# Jumps - Jumping on Pillars Game : 35.0
# Dream Team - be your own fantasy football manager : 35.0
# Chain: Collaborate On MyVideo Story/Group Video : 35.0
# Ready Jet Go! Space Explorer : 34.0
# PIN Genie Vault – Secret photo album & Password : 34.0
# Lemon Lumberjack's Letter Mill : 34.0
# Clown Spotter - Find Clowns Around You : 34.0
# Pozzle Blocks : 33.0
# Being SalMan: The Official Game : 33.0
# BFB Champions 2.0 ~Football Club Manager~ : 33.0
# Smelly Baby - Farty Party : 32.0
# NFL Draft - Fan Mobile Pass : 32.0
# Gweep Gwop : 32.0
# Flip Heroes : 32.0
# Chinese Recipes - Asian cuisine : 32.0
# Vice Lipstick : 31.0
# Neon Horizon : 31.0
# Nature Cat's Great Outdoors : 31.0
# Flip Football - Soccer Manager Strategy Card Game : 31.0
# WKC Dog Show 2017 : 30.0
# VR SNIPER : 30.0
# VR Roller-Coaster : 30.0
# Thomas & Friends™: Read & Play : 30.0
# Nitro Heads : 30.0
# Nibmoji: Political Emojis : 30.0
# Buildy Blocks : 30.0
# iPaint uPaint : 29.0
# VR Crazy Bike Race: Traffic Racing Free : 29.0
# Tip Tap Soccer : 29.0
# Santa Tracker - Where is Santa Claus? : 29.0
# MyDx One: Find a Strain that Works for You : 29.0
# Lieferheld - Delicious food delivery service : 29.0
# Lieferando.de : 29.0
# Fantasy Football Coach : 29.0
# Escape Game: Traps : 29.0
# Alternative Girls : 29.0
# US Presidential Election 2016 - Polls : 28.0
# Sky Pillar : 27.0
# Puzzle it to 10 : 27.0
# Into Mirror : 27.0
# GoldenMoji - Golden Retriever Emojis : 27.0
# Fairy Princess Fashion Design : 27.0
# Shogi : 26.0
# Laurie Hernandez the Human Emoji : 26.0
# Immortal Legends - TD : 26.0
# Billion Hunter - Casual Monster Clicker RPG : 26.0
# WRAL Weather Alert : 25.0
# State Council - Official Chinese government app : 25.0
# NeverKnew - Game night is back : 25.0
# LOOKS - Real Makeup Camera : 25.0
# Bridge Rider : 25.0
# Météo-France : 24.0
# Happy Oink : 24.0
# Basketball Free Throw : 24.0
# Programme TV Télé Loisirs : 23.0
# Escape Game: illumination : 23.0
# Zombie Town Story : 22.0
# VR Death Simulator : 22.0
# Stick Soccer 2 : 22.0
# SenseSleep - Train Your Brain To Sleep Better : 22.0
# McDo France : 22.0
# JaxReady : 22.0
# Evil Zombie Graveyard Apocalypse Shooting VR Games : 22.0
# Cube Roll : 22.0
# Ab in den Urlaub – Pauschalreisen günstig buchen : 22.0
# 3D Maze Level 100 : 22.0
# VR Haunted House 3D : 21.0
# Princess Swimming & Spa - Girls Beauty Game FREE : 21.0
# Juju On That Beat  - Dance Challenge Game : 21.0
# Face Up - The Selfie Game : 21.0
# Escape Game: Christmas Eve : 21.0
# DailyCast - Aggregate Hot New Videos : 21.0
# Crazy Maze - Traffic Puzzle : 21.0
# C CHANNEL -Watch tips & tricks videos for girls : 21.0
# SHOWROOM - video live streaming : 20.0
# Room Escape [SECRET CODE 2] : 20.0
# Go Karts - VR : 20.0
# Dice Mania - Play Free Online Classic Board Game with Friends : 20.0
# Chefkoch - Rezepte, Kochen, Backen & Kochbuch : 20.0
# Wild City Rush - Urban Jungle Adventure : 19.0
# Wall Switch : 19.0
# Snail Sleep-Dream Talk Recording : 19.0
# SFR Mon Compte : 19.0
# Parallels : 19.0
# Hey Duggee: The Tinsel Badge : 19.0
# Circle Boom2 - Wheel Puzzle Game : 19.0
# Stickman Forest Swing : 18.0
# Rise! : 18.0
# JD Sports : 18.0
# Gravity Island - Shiro's Adventure : 18.0
# Final Kick VR - Virtual Reality free soccer game for Google Cardboard : 18.0
# Demolition Derby Virtual Reality (VR) Racing : 18.0
# TraptionBakery : 17.0
# TENOSEL+ : 17.0
# Smart Music: Streaming Videos and Radio : 17.0
# Show My Homework : 17.0
# PINKFONG 123 Numbers : 17.0
# My Sweet Farm : 17.0
# Ma Banque : 17.0
# Lloyds Bank Mobile Banking : 17.0
# Hoverboard Rush Racing Simulator -Hover Board Game : 17.0
# Face Swap-r : 17.0
# in-capturing moments in life : 16.0
# Tangled Up! - Valentine Special : 16.0
# Rubin.io : 16.0
# Earth Defender S - Trillion Battle Game : 16.0
# Super Adventures World HD : 15.0
# Political Knockout PKO Presidential Fight : 15.0
# LINE RUSH ! : 15.0
# Fill - one-line puzzle game : 15.0
# Everfilter - transform your photos into artworks : 15.0
# Aeronaut : 15.0
# VR Thrills: Roller Coaster 360 (Google Cardboard) : 14.0
# VPN Express : 14.0
# ON-SEN - escape game - : 14.0
# Jottit : 14.0
# Iron Mission- classic arcade shoot'em up : 14.0
# Grandpa, what the fone? : 14.0
# Freddy the Frogcaster's Weather Station : 14.0
# Cubed Rally World : 14.0
# Crooked Path : 14.0
# Crazy Truck! : 14.0
# Cola Bottle Flip Challenge : 14.0
# CCTV5 : 14.0
# Steps! - Hardest Action Game Ever! : 13.0
# Buzzy Bubbles : 13.0
# BOSS Tuner : 13.0
# SnapMatch - Single and Group Matching : 12.0
# Monster Zombie Plague War - Virtual Reality (VR) : 12.0
# GoSnaps - Share Screenshots for Pokémon GO : 12.0
# Aussie Rules Hero - Footy Goal Kicking Game : 12.0
# Aquarium VR : 12.0
# Almanac Long-Range Weather Forecast : 12.0
# Showroomprive - Private Fashion Sales : 11.0
# Mon Espace - Pôle emploi : 11.0
# Magnets! : 11.0
# Again - room escape game : 11.0
# VR-Crazy Car Traffic Racing : 10.0
# Suica : 10.0
# Room Escape Game - Santa's Room : 10.0
# Risky Rooms : 10.0
# Quizduell : 10.0
# Peatix -Discover events & communities in your city : 10.0
# My8to18 : 10.0
# Juju on that Beat Challenge : 10.0
# Free QR Code Reader simply to scan a QR Code : 10.0
# Emergency Surgery Simulator - Doctor Game FOR FREE : 10.0
# Chick Go & Climb : 10.0
# Catch the Bus : 10.0
# Book - room escape game - : 10.0
# Youmiam : 9.0
# Stop! Thief!! : 9.0
# NightShooting : 9.0
# MangaZERO - comic reader : 9.0
# Mahjong Panda : 9.0
# Little Panda Mini Games-3D : 9.0
# Hop Rush : 9.0
# Fabe Bird - The Flappy Challenge Adventure : 9.0
# Escape from the wedding hall. : 9.0
# Building World - Create Your Castle & City : 9.0
# minne - shopping handmade item : 8.0
# ameli, l'Assurance Maladie : 8.0
# World Spin - Create & Play : 8.0
# Real Bike Traffic Rider Virtual Reality Glasses : 8.0
# My Vodafone : 8.0
# La Banque Postale : 8.0
# Halifax Mobile Banking : 8.0
# Escape Alice House2 : 8.0
# Dash Up 2 : 8.0
# botman - Real time video chat : 7.0
# Stylish School Timetable : 7.0
# SNCF : 7.0
# Roller Coaster Simulator - Draw and Simulate! : 7.0
# Merry Christmas -Activities : 7.0
# Levels - Addictive Puzzle Game : 7.0
# Home Run X 3D - Baseball Batting Game : 7.0
# Escape the Cake Café : 7.0
# Escape from the Art Gallery. : 7.0
# Dice Crush : 7.0
# Deamon's Dungeon : 7.0
# Circle Boom : 7.0
# Cat Monsters : 7.0
# Ao Oni2 : 7.0
# 鬼とび : 6.0
# Welcome to Virtual Reality : 6.0
# VR Horror Maze Walk :Horror Fever For VR Cardboard : 6.0
# VIBO RealMassager : 6.0
# The Krustashians : 6.0
# Slots of Vegas - Play Free Casino slot machines! : 6.0
# Room Escape Game - Pictures Room Esacpe : 6.0
# Pirates Kids Room Escape : 6.0
# MixChannel : 6.0
# Mastering the piano with Lang Lang : 6.0
# Le Fooding Restaurant and Stylish Bedrooms Guide : 6.0
# Baby Panda's Carnival : 6.0
# Railway Route Search : 5.0
# New baseball board app BasePinBall : 5.0
# Free IQ Test: Calculate your IQ : 5.0
# FizzUp – Online Fitness Trainer : 5.0
# Escape the Ice Cream Parlor : 5.0
# Escape from the grandma house in the countryside. : 5.0
# Escape from the ICU room. : 5.0
# Escape Game: Red room : 5.0
# Dungeon Witcher : 5.0
# Driving test 2017 : 5.0
# Cutie Patootie - Xmas Surprise : 5.0
# Brake or Break : 5.0
# Auto Palmistry : 5.0
# Advent Calendar 2017 - The Game : 5.0
# Simple Camera - Fast Minimal Design : 3.0
# Inner Circle : 3.0
# Escape the Sweet Shop Series : 3.0
# Escape from the living room during the Obon holiday. : 3.0
# Escape from the frigid Igloo. : 3.0
# Escape from the beach house of everlasting summer. : 3.0
# Escape a Crepe House : 3.0
# a. - Physical Simulation Puzzle Game : 2.0
# Wire de Coins 2 : 2.0
# SwapperFace - Face Swap Free, Live Mask Effects : 2.0
# Survivor: Prologue : 2.0
# Soccer Cup Championship 2016 : 2.0
# ROAD -escape game- : 2.0
# Online Reversi World : 2.0
# Marmiton Twist : 2.0
# Escape from the pit latrine. : 2.0
# Escape Game : Escape from Okinawa : 2.0
# Dash Heroes : 2.0
# Circle Swing : 2.0
# Bounce Balls - Strike Game : 2.0
# 4 Bilder 1 Wort : 2.0
# Video speed editor - VBooster : 1.0
# Video Smith - A Powerful video editing tool set : 1.0
# Versus - Multiplayer Game (2 players) : 1.0
# Trail Jump : 1.0
# There's no tablecloth I can't pull!! : 1.0
# Team GB Live : 1.0
# Smart Matches ~ Puzzles with Matchsticks : 1.0
# SLAAAASH ! -Cut and Smash ! refreshing Puzzle- : 1.0
# Race Calendar 2016 : 1.0
# Open Food Facts : 1.0
# One More Spin! - Free Vegas Casino Slots : 1.0
# Money Multiplier : 1.0
# LINE Moments - Capture Your Fun Moments : 1.0
# LINE FIGHTERS : 1.0
# Jeremstar box : 1.0
# IQ200 - If you can clear all stage : 1.0
# Frantic Ball : 1.0
# Escape from the music room in the school. : 1.0
# Escape from many tutoring school of test. : 1.0
# Escape Game Darkness LittleRedHood : 1.0
# DelusionCreatureGacha : 1.0
# Bike Race Level 100 : 1.0
# Baidu Videos : 1.0
# ｗｗｗ : 0.0
# 針の穴 : 0.0
# 謎解き2016 : 0.0
# 謎解き : 0.0
# 花札Online : 0.0
# 素飛び : 0.0
# 秒速 : 0.0
# 机でGOLF : 0.0
# 教えて!goo : 0.0
# 指神 : 0.0
# 币优铺 : 0.0
# 屠龙杀 : 0.0
# 大富豪 Online : 0.0
# 和我信 : 0.0
# 任务客 : 0.0
# ブリ猫 : 0.0
# のび毛 : 0.0
# wetter.com : 0.0
# vente-privee : 0.0
# striker – dropping balls : 0.0
# skyticket - Reserve Best Valued Air Tickets : 0.0
# real happy majiang-all stars majiang,mahjong : 0.0
# niconico ch : 0.0
# ikouhoushi : 0.0
# iSleeping by iSommeil SARL : 0.0
# gogogo : 0.0
# francetv JO – Regarder les Jeux Olympiques de Rio 2016 : 0.0
# camera for filter : 0.0
# bit-tube - Live Stream Video Chat : 0.0
# airweave sleep analysis : 0.0
# Wi-Fiミレル : 0.0
# When you clear one,million yen CHANCE!! : 0.0
# WarnWetter : 0.0
# VoiceTra(Voice Translator) : 0.0
# Uncolored Boy : 0.0
# U Compass ( North, South, East and West ) : 0.0
# TransParent Compass : 0.0
# Toy Blocks Game for Brain Traning -TSUMIKI- : 0.0
# TownWiFi - WiFi Everywhere : 0.0
# TodayAir : 0.0
# Tiny Bone : 0.0
# Theory of evolution : 0.0
# The Pocket Quiz for Pokemon : 0.0
# The Bad Man Tipster - Betting Tips : 0.0
# Tetro Blocks - Beat IQ with Tetrix-style-puzzle. : 0.0
# Tetminos - Classic Puzzle Game : 0.0
# Tchapper Messenger - Keep it private : 0.0
# Tapping Monsters : 0.0
# TLMJ, Tout Le Monde Joue : 0.0
# Suppin Detective: Expose their true visage! : 0.0
# Superdrug : 0.0
# Super Knock and Run : 0.0
# Sumikko gurashi-Puzzling Ways : 0.0
# Stress Release Grenade : 0.0
# StageCameraHD : 0.0
# Spring Festival by BabyBus : 0.0
# Sonia Tlev : 0.0
# Soccer Puzzle for Brain Training -SoccerStrike- : 0.0
# Smart Channel -New Style of News Reader- : 0.0
# Simple Reversi Online : 0.0
# Shark Boom - Challenge Friends with your Pet : 0.0
# Samurai Ninja Puzzle ONIMARU : 0.0
# SUDOKU -The puzzle game that makes your brain younger!- : 0.0
# SPEED:3D Racing : 0.0
# S, - Puzzle Game With Create Level Feature : 0.0
# Reversi REAL - Multiplayer Board game : 0.0
# Refreshing ! Brain training fit : 0.0
# RadiTube - great radio player for am/fm radios : 0.0
# REVERSI ZERO - free classic game : 0.0
# Qu'est-ce que je sais vraiment ? : 0.0
# Puzzle Game for Brain Training!! PITATTO!! : 0.0
# Puzzle Game for Brain Training -KITINTO- : 0.0
# Poker - Texas Holdem HD Poker : 0.0
# Pokelog for PokemonGO : 0.0
# Pictalive for Live Photos - Create from videos : 0.0
# PetitLyrics : 0.0
# Particular : 0.0
# Pantheon Warfare: The Chaos of Knights : 0.0
# Otaku quizzes from manga, and anime--Slice HEROES! : 0.0
# Official QR Code reader "Q" - QR app. - : 0.0
# Ocean Overlord - Global War : 0.0
# NumberQ : 0.0
# Natoo : 0.0
# Myth Kingdom:Wrath of Gauss : 0.0
# My au : 0.0
# MeiCam -  Video Production Master : 0.0
# Match 3 Puzzle - Mr.Rockets - : 0.0
# MangaTiara - love comic reader : 0.0
# Malodo : Stop au mal de dos : 0.0
# METAL SAGA -Ark in the wild land- : 0.0
# MATCH ON LINE chat : 0.0
# Limite Limite : 0.0
# Les Anges : 0.0
# LINE BLOG : 0.0
# LEAD ZAQ Battle Version : 0.0
# Kuro no Sekai - It's a Darkness World : 0.0
# Kungfu Street-Ultimate Fight : 0.0
# KATWARN : 0.0
# Jishokun-Japanese English Dictionary & Translator : 0.0
# Jigsaw Puzzle for Brain Training -PITATOY- : 0.0
# JCnews - Anime & Game Culture : 0.0
# Intuition Guidances : 0.0
# Instant X - Take instant-camera-like photo with double exposure and bulb mode : 0.0
# Impots.gouv : 0.0
# ImpossibleGO! - You can't clear : 0.0
# Impossible Goal 3D : 0.0
# Human Juggling Cup : 0.0
# Hugsafe Petracker : 0.0
# HowDidiDo : 0.0
# HOLE. : 0.0
# Golden Lotus Slots : 0.0
# Go!Go!Cat! : 0.0
# Go! No. MM! Even amateur exit the record? : 0.0
# GhostCallDX : 0.0
# GYMONDO – Fitness Training für Zuhause : 0.0
# GE's eddie : 0.0
# Fusion Pictures - A Multiplayer Game with 4 Hidden Pics Object & 1 Word Puzzle : 0.0
# Free Gameplay Video, Walkthroughs, News for Pokémon GO : 0.0
# Fluege.de - Finde den billigsten Flug : 0.0
# FFmoji 2016 - Your Fantasy Football Emoji Keyboard : 0.0
# Escape from the Bears of the student council room. : 0.0
# Escape a Halloween Candy Shop : 0.0
# Escape Game  Escape from Lost Memory : 0.0
# Emojil - original emoji stamp, decoration camera : 0.0
# Eat Game : 0.0
# Ear Age Diagnosis : 0.0
# EOPAN : 0.0
# DropEraser : 0.0
# Dinosaur Planet : 0.0
# Digiposte + : 0.0
# Devil Lord: I shouldn't say that...half of world : 0.0
# Der IQ Test - Intelligenztest (Deutsch) : 0.0
# DaWanda - The marketplace for unique products : 0.0
# Cyber Reversi : 0.0
# CelebrityDiagnosis! : 0.0
# CelebrityCamera! : 0.0
# Caf - Mon Compte : 0.0
# BrainTraining!!GASHAAAAAAN!! : 0.0
# BlurEffect-Blur Photo & Video, Hide Face : 0.0
# Billiards9 : 0.0
# Billiards8 (8 Ball & Mission) : 0.0
# BestieBox : 0.0
# Beautiful Japanese Handwriting for iPhone : 0.0
# Beautiful Japanese Handwriting : 0.0
# Beast Poker : 0.0
# BarcodeReader「ICONIT」 : 0.0
# Baby Panda's Bath Time : 0.0
# Baby Learns Transportation : 0.0
# Auto IV Calc for PokemonGO : 0.0
# 2Face Fitpack - Dein Trainingsprogramm mit persönlichem Ernährungsplan, Kalorienrechner und Trainingsplan : 0.0
# ! OH Fantastic Free Kick + Kick Wall Challenge : 0.0

# %%
android_realistic = []
ios_realistic = []

for app in android_final:
    # instalações na coluna 5
    installs = app[5]
    installs = installs.replace('+','')
    installs = float(installs.replace(',',''))
    if installs <= 10000000:
        android_realistic.append(app)
        
    
for app in ios_final:
    # rating count na coluna 6
    rating_count = float(app[6])
    if rating_count <= 100000:
        ios_realistic.append(app)

print(len(android_realistic), len(ios_realistic))
# Out:
# 8427 3021

# %%
ios_category_avgR = category_avg(ios_realistic, 12, 6)
print('Média de quantidade de avaliações de usuários por aplicativo do gênero na App Store, para \naplicativos com menos de 100.000 avaliações:\n')
display_dict_decrescent(ios_category_avgR)
print('\n\n')

android_category_avgR = category_avg(android_realistic, 1, 5)
print('Média de instalações por aplicativo do gênero na Google Play, para aplicativos com menos de \n10.000.000 de instalações:\n')
display_dict_decrescent(android_category_avgR)
print('\n\n')
# Out:
# Média de quantidade de avaliações de usuários por aplicativo do gênero na App Store, para
# aplicativos com menos de 100.000 avaliações:
#
# Book : 16605.75
# Social Networking : 13900.021052631579
# Shopping : 12601.987012987012
# Productivity : 12377.692307692309
# Finance : 10506.354838709678
# Sports : 10314.09375
# Reference : 10186.9375
# Photo & Video : 9317.454545454546
# Utilities : 8676.57142857143
# Travel : 8490.081081081082
# Music : 8395.543859649122
# Entertainment : 8260.150406504064
# News : 7850.45
# Business : 7491.117647058823
# Weather : 7454.772727272727
# Games : 6862.17356778219
# Health & Fitness : 6417.3442622950815
# Lifestyle : 5297.666666666667
# Education : 4660.163793103448
# Navigation : 4146.25
# Catalogs : 4004.0
# Food & Drink : 3678.0454545454545
# Medical : 612.0
#
#
#
# Média de instalações por aplicativo do gênero na Google Play, para aplicativos com menos de
# 10.000.000 de instalações:
#
# ENTERTAINMENT : 3808684.210526316
# PHOTOGRAPHY : 3437585.522727273
# GAME : 3244832.8229027963
# SHOPPING : 2942987.085561497
# WEATHER : 2392365.970149254
# VIDEO_PLAYERS : 2369512.285714286
# COMMUNICATION : 2319787.355731225
# SOCIAL : 2008540.8348623854
# TRAVEL_AND_LOCAL : 1993454.9797979798
# FOOD_AND_DRINK : 1924897.7363636363
# SPORTS : 1867228.3664383562
# EDUCATION : 1833495.145631068
# HEALTH_AND_FITNESS : 1827957.0444444444
# PRODUCTIVITY : 1735991.391025641
# PERSONALIZATION : 1705465.793594306
# MAPS_AND_NAVIGATION : 1692173.1666666667
# TOOLS : 1649059.4183381088
# BOOKS_AND_REFERENCE : 1437212.2162162163
# FAMILY : 1437091.164929491
# HOUSE_AND_HOME : 1331540.5616438356
# NEWS_AND_MAGAZINES : 1304083.0327868853
# ART_AND_DESIGN : 1128948.2142857143
# LIFESTYLE : 1010129.1540697674
# FINANCE : 936083.226993865
# DATING : 854028.8303030303
# COMICS : 817657.2727272727
# AUTO_AND_VEHICLES : 647317.8170731707
# LIBRARIES_AND_DEMO : 638503.734939759
# BUSINESS : 617255.225
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120550.61980830671

# %% [markdown]
# ### Conclusões
#
# Vemos que o gênero Books na App Store tem a maior média de quantidade de avaliações nas limitações impostas pela análise e não é um gênero tão saturado como o de Games. Na Google Play, a categoria Books também tem boa média de instalações por aplicativo, porém posta para baixo devido à sua menor abrangência de aplicativos, visto que outras categorias existentes na Google Play e não na App Store, como Comics e Libraries and Demos, repartem esses dados. Desta forma, recomenda-se a criação de um aplicativo relacionado a livros para a entrada do mercado da empresa CVTech.
